# %% [markdown]
# # Loading the gdrive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# # Importing the Libraries

# %%
import numpy as np                    # Mathematical Calculations
import pandas as pd                   # Manipulation of raw data
import matplotlib.pyplot as plt       # Plotting the graphs
import seaborn as sns
import plotly.express as px           # For creating interactive publication quality graphs
# %matplotlib inline

# %% [markdown]
# # Importing the Dataset

# %%
data = pd.read_excel('/gdrive/My Drive/TROP-ICSU-Internship-Sahil-Ashutosh/Assignment-1-Emissions/Analysis/Data/1991-2019/GHG/Greenhouse_Gases_(1991-2019).xlsx')

# %%
data.head()
# Out:
#        country  year    co2  methane  nitrous_oxide  total_ghg
# 0  Afghanistan  1991  2.427     9.07           3.30      15.06
# 1  Afghanistan  1992  1.379     9.00           3.21      13.60
# 2  Afghanistan  1993  1.333     8.90           3.21      13.43
# 3  Afghanistan  1994  1.282     8.97           2.99      13.24
# 4  Afghanistan  1995  1.230     9.15           3.07      13.45

# %%
data.tail()
# Out:
#        country  year     co2  methane  nitrous_oxide  total_ghg
# 5705  Zimbabwe  2015  12.170    11.87           6.68      67.49
# 5706  Zimbabwe  2016  10.815    11.92           6.55      65.98
# 5707  Zimbabwe  2017  10.247    11.92           6.55      65.98
# 5708  Zimbabwe  2018  11.341    11.92           6.55      65.98
# 5709  Zimbabwe  2019  10.374    11.92           6.55      65.98

# %%
data = data.round(4)

# %%
data.drop('total_ghg', axis = 1, inplace = True)

# %% [markdown]
# # Normalizing the data into the scale of 0 and +1 by using min-max scaler function

# %%
from sklearn.preprocessing import MinMaxScaler
# Storing the MinMaxScaler in the variable scalerr
scaler = MinMaxScaler()

# %%
# Performing the scaling on the co2 attribute
scaler.fit(data[['co2']])
data[['co2']]=scaler.transform(data[['co2']])
data.head()
# Out:
#        country  year       co2  methane  nitrous_oxide
# 0  Afghanistan  1991  0.000236     9.07           3.30
# 1  Afghanistan  1992  0.000133     9.00           3.21
# 2  Afghanistan  1993  0.000129     8.90           3.21
# 3  Afghanistan  1994  0.000124     8.97           2.99
# 4  Afghanistan  1995  0.000119     9.15           3.07

# %%
# Performing the scaling on the methane attribute
scaler.fit(data[['methane']])
data[['methane']]=scaler.transform(data[['methane']])
data.head()
# Out:
#        country  year       co2   methane  nitrous_oxide
# 0  Afghanistan  1991  0.000236  0.007170           3.30
# 1  Afghanistan  1992  0.000133  0.007115           3.21
# 2  Afghanistan  1993  0.000129  0.007036           3.21
# 3  Afghanistan  1994  0.000124  0.007091           2.99
# 4  Afghanistan  1995  0.000119  0.007234           3.07

# %%
# Performing the scaling on the nitrous_oxide attribute
scaler.fit(data[['nitrous_oxide']])
data[['nitrous_oxide']]=scaler.transform(data[['nitrous_oxide']])
data.head()
# Out:
#        country  year       co2   methane  nitrous_oxide
# 0  Afghanistan  1991  0.000236  0.007170       0.005907
# 1  Afghanistan  1992  0.000133  0.007115       0.005745
# 2  Afghanistan  1993  0.000129  0.007036       0.005745
# 3  Afghanistan  1994  0.000124  0.007091       0.005350
# 4  Afghanistan  1995  0.000119  0.007234       0.005494

# %% [markdown]
# # Creating some interactive graphs and maps for CO2 emiss
2'], ascending=True).head(5)['country'].tolist()

plt.figure(figsize=(10,10))
g = sns.barplot(
    data = data[data['country'].isin(bottom_co2)],
    x ='country',
    y ='co2',
    order = bottom_co2,
    ci=None
)
plt.title('Bottom  countries with lowest CO2 emissions  measured in Million Tonnes Per Year')
plt.show()

# %%
# Creating a time series chloropleth map for CO2 emissions 
fig = px.choropleth(
    data.groupby(['country', 'year'])['co2'].sum().reset_index().sort_values(by=['year'], ascending=True),
    locations='country',
    locationmode='country names',
    color='co2',
    color_continuous_scale='Spectral_r', # (_r) is used for inverting the color ramp
    height=750,
    animation_frame='year',
    animation_group='country'
)

fig.update_layout(
    title='CO2 Emissions in Million Tonnes Per Year'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9216451d-2cdb-4501-8633-6dd01783af68" class="plotly-graph-div" style="height:750px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9216451d-2cdb-4501-8633-6dd01783af68")) {
#                     Plotly.newPlot(
#                         '9216451d-2cdb-4501-8633-6dd01783af68',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "year=1991<br>country=%{location}<br>co2=%{z}", "ids": ["Afghanistan", "Armenia", "Serbia", "Denmark", "Ireland", "Senegal", "Djibouti", "Iraq", "Namibia", "Bosnia and Herzegovina", "Thailand", "Aruba", "Saudi Arabia", "Dominica", "Iran", "Nepal", "Sao Tome and Principe", "Dominican Republic", "United States", "Saint Vincent and the Grenadines", "New Zealand", "Iceland", "Ecuador", "Samoa", "Uzbekistan", "New Caledonia", "India", "Togo", "Bolivia", "Netherlands", "Indonesia", "Uruguay", "Australia", "Egypt", "Democratic Republic of Congo", "Botswana", "Anguilla", "Slovakia", "Cote dIvoire", "Kenya", "Moldova", "Brunei", "Kazakhstan", "Mongolia", "Sint Maarten (Dutch part)", "Croatia", "Venezuela", "Tajikistan", "Antigua and Barbuda", "Jordan", "Montenegro", "Singapore", "Cuba", "Mozambique", "Seychelles", "Italy", "Czechia", "Morocco", "Jamaica", "Israel", "Argentina", "Vanuatu", "Cyprus", "Sierra Leone", "Montserrat", "Japan", "Brazil", "Tanzania", "Hungary", "Bhutan", "Nicaragua", "Guatemala", "Oceania", "Belize", "Grenada", "Oman", "Poland", "Finland", "Greenland", "Turkey", "Uganda", "Bangladesh", "France", "Greece", "Pakistan", "Belgium", "Philippines", "French Polynesia", "Papua New Guinea", "Georgia", "Belarus", "Gambia", "Paraguay", "Panama", "Fiji", "Germany", "Turks and Caicos Islands", "Gabon", "Turkmenistan", "Peru", "Palestine", "Ghana", "Barbados", "Bahrain", "Portugal", "Ukraine", "Haiti", "Eritrea", "Azerbaijan", "Bermuda", "Saint Lucia", "Niger", "Nigeria", "Honduras", "Equatorial Guinea", "Saint Pierre and Miquelon", "El Salvador", "Hong Kong", "Tonga", "Austria", "United Kingdom", "Costa Rica", "Trinidad and Tobago", "Guyana", "Ethiopia", "Qatar", "Norway", "Guinea", "Tunisia", "North Macedonia", "Russia", "Guinea-Bissau", "Bahamas", "Eswatini", "Romania", "United Arab Emirates", "Estonia", "North Korea", "Benin", "Slovenia", "Myanmar", "Micronesia", "Liechtenstein", "Comoros", "Switzerland", "Burundi", "Yemen", "Algeria", "Chile", "Canada", "Spain", "Solomon Islands", "Congo", "Angola", "Malaysia", "Liberia", "Mexico", "Macao", "Kyrgyzstan", "Mauritius", "Lesotho", "Laos", "Colombia", "Sudan", "Madagascar", "Malta", "Andorra", "Lebanon", "Zambia", "Latvia", "Mauritania", "China", "Central African Republic", "Burkina Faso", "Lithuania", "South Korea", "Somalia", "Syria", "Mali", "Luxembourg", "Cambodia", "South Africa", "Zimbabwe", "Vietnam", "Sweden", "Albania", "Kiribati", "Libya", "Malawi", "Bulgaria", "Taiwan", "Sri Lanka", "Cook Islands", "Chad", "Cameroon", "Kuwait", "Suriname"], "locationmode": "country names", "locations": ["Afghanistan", "Armenia", "Serbia", "Denmark", "Ireland", "Senegal", "Djibouti", "Iraq", "Namibia", "Bosnia and Herzegovina", "Thailand", "Aruba", "Saudi Arabia", "Dominica", "Iran", "Nepal", "Sao Tome and Principe", "Dominican Republic", "United States", "Saint Vincent and the Grenadines", "New Zealand", "Iceland", "Ecuador", "Samoa", "Uzbekistan", "New Caledonia", "India", "Togo", "Bolivia", "Netherlands", "Indonesia", "Uruguay", "Australia", "Egypt", "Democratic Republic of Congo", "Botswana", "Anguilla", "Slovakia", "Cote dIvoire", "Kenya", "Moldova", "Brunei", "Kazakhstan", "Mongolia", "Sint Maarten (Dutch part)", "Croatia", "Venezuela", "Tajikistan", "Antigua and Barbuda", "Jordan", "Montenegro", "Singapore", "Cuba", "Mozambique", "Seychelles", "Italy", "Czechia", "Morocco", "Jamaica", "Israel", "Argentina", "Vanuatu", "Cyprus", "Sierra Leone", "Montserrat", "Japan", "Brazil", "Tanzania", "Hungary", "Bhutan", "Nicaragua", "Guatemala", "Oceania", "Belize", "Grenada", "Oman", "Poland", "Finland", "Greenland", "Turkey", "Uganda", "Bangladesh", "France", "Greece", "Pakistan", "Belgium", "Philippines", "French Polynesia", "Papua New Guinea", "Georgia", "Belarus", "Gambia", "Paraguay", "Panama", "Fiji", "Germany", "Turks and Caicos Islands", "Gabon", "Turkmenistan",  ...

# %% [markdown]
# # Creating some interactive graphs and maps for methane emissions

# %%
# Showing the top 5 countries emitting the highest amount of Methane Emissions

top_methane = data.groupby('country')['methane'].sum().reset_index().sort_values(by=['methane'], ascending=False).head(5)['country'].tolist()

fig = px.line(
    data[data['country'].isin(top_methane)],
    x='year',
    y='methane',
    color='country',
    title = 'Top countries with highest Methane Emissions measured in Million Tonnes of Carbon Dioxide Equivalents '
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5313c0d4-1b67-4c96-8473-2f16ef2cd611" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5313c0d4-1b67-4c96-8473-2f16ef2cd611")) {
#                     Plotly.newPlot(
#                         '5313c0d4-1b67-4c96-8473-2f16ef2cd611',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Brazil<br>year=%{x}<br>methane=%{y}", "legendgroup": "country=Brazil", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "country=Brazil", "showlegend": true, "type": "scatter", "x": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [0.25053956407965783, 0.2540101667312299, 0.2547216798033061, 0.2592279292597892, 0.2595283458902214, 0.24792277711457733, 0.25458728288969174, 0.2669438932414164, 0.2670071388478231, 0.2590540038421706, 0.27882616154509016, 0.30401372429659024, 0.3158011241906538, 0.33059269038903955, 0.335336110869548, 0.32026784514313267, 0.3324584357780395, 0.31698697931078096, 0.31952470926785304, 0.34800104355250566, 0.3319208481235819, 0.3384114284810777, 0.32965191199373867, 0.3379528978346285, 0.3532504288842684, 0.35189064834652267, 0.3489995335636527, 0.34610762821070273, 0.34321651342783277], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=China<br>year=%{x}<br>methane=%{y}", "legendgroup": "country=China", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "country=China", "showlegend": true, "type": "scatter", "x": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [0.5891249179783542, 0.5959159149662822, 0.6005802784387821, 0.6133005510273457, 0.6329066890134476, 0.6520068621482951, 0.626613751175973, 0.6442118411586595, 0.6535089453004561, 0.6567028484239985, 0.6523151844795282, 0.6488999217335619, 0.6487892419223501, 0.6582760828833671, 0.6635412796167316, 0.6992987643389648, 0.7301784316670751, 0.7739206741981642, 0.8111249021669525, 0.8516099959680925, 0.8867903645318639, 0.9223027725292708, 0.9454506644741523, 0.9692231067823006, 0.9947031804634321, 1.0, 0.9869366199966795, 0.9738732399933592, 0.9608098599900387], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=India<br>year=%{x}<br>methane=%{y}", "legendgroup": "country=India", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "country=India", "showlegend": true, "type": "scatter", "x": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [0.4223304424820738, 0.42610146176407804, 0.43059980551976024, 0.4344735989121756, 0.44047402582001877, 0.44429247930682814, 0.44947071333138316, 0.45725782862021797, 0.4638669944897265, 0.46670514107723077, 0.4713220703449256, 0.46661817836842145, 0.47601015091982823, 0.48442181657192995, 0.49386912902894275, 0.5015929987113708, 0.5128744337541801, 0.5171672292890402, 0.5183847072123708, 0.5224008032192012, 0.5215627989343115, 0.5230174478816675, 0.521894838367947, 0.5216181388399174, 0.518835332158019, 0.524646022246642, 0.5221818153070179, 0.5197176083673937, 0.5172534014277695], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Russia<br>year=%{x}<br>methane=%{y}", "legendgroup": "country=Russia", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "country=Russia", "showlegend": true, "type": "scatter", "x": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [0.7183198804658039, 0.65289230063799, 0.6084859792396295, 0.5627910286107312, 0.5412954281332268, 0.5176099485338878, 0.49192432663193425, 0.49747412859412915, 0.48699116933220543, 0.5034745555019724, 0.5324094204330743, 0.5676609403040531, 0.6284162509585661, 0.6163363401348713, 0.6318789479093374, 0.6453107335699773, 0.6442276525602612, 0.6 ...
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.222222222222222

# %%
# Showing the bottom 5 countries emitting the lowest amount of Methane Emissions

bottom_methane = data.groupby('country')['methane'].sum().reset_index().sort_values(by=['methane'], ascending=True).head(5)['country'].tolist()

plt.figure(figsize=(15, 15))
g = sns.barplot(
    data = data[data['country'].isin(bottom_methane)],
    x ='country',
    y ='methane',
    order = bottom_methane,
    ci=None
)

#g.set(ylim=(0,0.004))
plt.title('Bottom countries with lowest  Methane Emissions measured in Million Tonnes of Carbon Dioxide Equivalents ')
plt.show()

# %%
# Creating a time series chloropleth map for  methane emissions
fig = px.choropleth(
    data.groupby(['country', 'year'])['methane'].sum().reset_index().sort_values(by=['year'], ascending=True),
    locations='country',
    locationmode='country names',
    color='methane',
    color_continuous_scale='Spectral_r', # (_r) is used for inverting the color ramp
    height=750,
    animation_frame='year',
    animation_group='country'
)

fig.update_layout(
    title=' Methane Emissions'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e12d358b-52a3-42e4-9cdb-e436a797a21b" class="plotly-graph-div" style="height:750px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e12d358b-52a3-42e4-9cdb-e436a797a21b")) {
#                     Plotly.newPlot(
#                         'e12d358b-52a3-42e4-9cdb-e436a797a21b',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "year=1991<br>country=%{location}<br>methane=%{z}", "ids": ["Afghanistan", "Armenia", "Serbia", "Denmark", "Ireland", "Senegal", "Djibouti", "Iraq", "Namibia", "Bosnia and Herzegovina", "Thailand", "Aruba", "Saudi Arabia", "Dominica", "Iran", "Nepal", "Sao Tome and Principe", "Dominican Republic", "United States", "Saint Vincent and the Grenadines", "New Zealand", "Iceland", "Ecuador", "Samoa", "Uzbekistan", "New Caledonia", "India", "Togo", "Bolivia", "Net
Mongolia", "Sint Maarten (Dutch part)", "Croatia", "Venezuela", "Tajikistan", "Antigua and Barbuda", "Jordan", "Montenegro", "Singapore", "Cuba", "Mozambique", "Seychelles", "Italy", "Czechia", "Morocco", "Jamaica", "Israel", "Argentina", "Vanuatu", "Cyprus", "Sierra Leone", "Montserrat", "Japan", "Brazil", "Tanzania", "Hungary", "Bhutan", "Nicaragua", "Guatemala", "Oceania", "Belize", "Grenada", "Oman", "Poland", "Finland", "Greenland", "Turkey", "Uganda", "Bangladesh", "France", "Greece", "Pakistan", "Belgium", "Philippines", "French Polynesia", "Papua New Guinea", "Georgia", "Belarus", "Gambia", "Paraguay", "Panama", "Fiji", "Germany", "Turks and Caicos Islands", "Gabon", "Turkmenista ...

# %% [markdown]
# # Creating some interactive graphs and maps for Nitrous Oxide Emissions

# %%
# Showing the top 5 countries emitting the highest amount of nitrous oxide

top_nitrous_oxide = data.groupby('country')['nitrous_oxide'].sum().reset_index().sort_values(by=['nitrous_oxide'], ascending=False).head(5)['country'].tolist()

fig = px.line(
    data[data['country'].isin(top_nitrous_oxide)],
    x='year',
    y='nitrous_oxide',
    color='country',
    title = 'Top countries with highest Nitrous Oxide Emissions measured in Million Tonnes of Carbon Dioxide Equivalents '
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="09f09566-5658-4c3f-a4d9-d0593be71b36" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("09f09566-5658-4c3f-a4d9-d0593be71b36")) {
#                     Plotly.newPlot(
#                         '09f09566-5658-4c3f-a4d9-d0593be71b36',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Brazil<br>year=%{x}<br>nitrous_oxide=%{y}", "legendgroup": "country=Brazil", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "country=Brazil", "showlegend": true, "type": "scatter", "x": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [0.21103470563944196, 0.21374580318509076, 0.21859346104817137, 0.22451837621415874, 0.2262778964755732, 0.20941881968508178, 0.2164030378655942, 0.23464459486148265, 0.2323464459486148, 0.22475178196312187, 0.24012065281792555, 0.26751889688852176, 0.27631649819559395, 0.29615598685746086, 0.2977539185234393, 0.2855450024238289, 0.30551017110436823, 0.2823491390918721, 0.2745928865109431, 0.3184013501624863, 0.30445086808984323, 0.30990897175790433, 0.30488177101100594, 0.320627681921827, 0.32434421961685544, 0.3282941630608471, 0.32553638436540566, 0.32277860566996425, 0.32002082697452283], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=China<br>year=%{x}<br>nitrous_oxide=%{y}", "legendgroup": "country=China", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "country=China", "showlegend": true, "type": "scatter", "x": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [0.5718979478248379, 0.5815753092626174, 0.5645187352999264, 0.5881106702335852, 0.6640932186652782, 0.7090148481964917, 0.6596764637233603, 0.6752607860387453, 0.7048314990035369, 0.692012137098946, 0.6957825376591199, 0.7301111370450832, 0.7364669551322333, 0.7568271181571719, 0.7699696572526348, 0.7907248146219724, 0.8068118570120473, 0.8384832217175071, 0.8597410991615347, 0.8855234572777708, 0.8974271504748909, 0.9172307305599942, 0.9409662998007073, 0.964001651794531, 0.9928182846472879, 1.0, 0.9867497351742464, 0.9734976749196546, 0.960247410093901], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=India<br>year=%{x}<br>nitrous_oxide=%{y}", "legendgroup": "country=India", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "country=India", "showlegend": true, "type": "scatter", "x": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [0.26162989029929795, 0.26915273713126375, 0.2754008294881232, 0.28547318527030174, 0.2936064779072481, 0.3013268219114135, 0.3126021150151713, 0.3218126649550245, 0.3299459575919708, 0.3253676140546169, 0.3331059123471641, 0.3221178878575147, 0.33719949009820993, 0.3503779377704364, 0.3654954485878952, 0.382480205397059, 0.3997163222435678, 0.4060003231771908, 0.41926854229132626, 0.4327881214428066, 0.4429682029552758, 0.4420884428245686, 0.438461676571449, 0.441567768461497, 0.44454818033287247, 0.4442250031420004, 0.4408334380666822, 0.4374400775625258, 0.43404851248720755], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Indonesia<br>year=%{x}<br>nitrous_oxide=%{y}", "legendgroup": "country=Indonesia", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "country=Indonesia", "showlegend": true, "type": "scatter", "x": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [0.125590247230551, 0.12925292206043412, 0.12724204176167478, 0.1298813221537964, 0.13379535702102446, 0.1248002585417527, 0.1852703018115877, 0.14243136973266066, 0.12176598380523188, 0.11980896637161785, 0.12047327504174372, 0.15541232023268756, 0.13311309406251684, 0.15939817225344274, 0.14295204409573226, 0. ...
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscal

# %%
# Showing the bottom 5 countries emitting the lowest amount of Nitrous Oxide

bottom_nitrous_oxide = data.groupby('country')['nitrous_oxide'].sum().reset_index().sort_values(by=['nitrous_oxide'], ascending=True).head(5)['country'].tolist()

plt.figure(figsize=(15, 15))
g = sns.barplot(
    data = data[data['country'].isin(bottom_nitrous_oxide)],
    x ='country',
    y ='nitrous_oxide',
    order = bottom_nitrous_oxide,
    ci=None
)

# g.set(ylim=(0,0.004))
plt.title('Bottom 5 countries with lowest CO2 emissions from gas flaring in Million Tonnes Per Year')
plt.show()

# %%
# Creating a time series chloropleth map for nitrous_oxide
fig = px.choropleth(
    data.groupby(['country', 'year'])['nitrous_oxide'].sum().reset_index().sort_values(by=['year'], ascending=True),
    locations='country',
    locationmode='country names',
    color='nitrous_oxide',
    color_continuous_scale='Spectral_r', # (_r) is used for inverting the color ramp
    height=750,
    animation_frame='year',
    animation_group='country'
)

fig.update_layout(
    title='Nitrous Oxide Emissions'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="994c3ce2-e0f9-46e5-ae9a-bc943ecb375b" class="plotly-graph-div" style="height:750px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("994c3ce2-e0f9-46e5-ae9a-bc943ecb375b")) {
#                     Plotly.newPlot(
#                         '994c3ce2-e0f9-46e5-ae9a-bc943ecb375b',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "year=1991<br>country=%{location}<br>nitrous_oxide=%{z}", "ids": ["Afghanistan", "Armenia", "Serbia", "Denmark", "Ireland", "Senegal", "Djibouti", "Iraq", "Namibia", "Bosnia and Herzegovina", "Thailand", "Aruba", "Saudi Arabia", "Dominica", "Iran", "Nepal", "Sao Tome and Principe", "Dominican Republic", "United States", "Saint Vincent and the Grenadines", "New Zealand", "Iceland", "Ecuador", "Samoa", "Uzbekistan", "New Caledonia", "India", "Togo", "Bolivia", "Netherlands", "Indonesia", "Uruguay", "Australia", "Egypt", "Democratic Republic of Congo", "Botswana", "Anguilla", "Slovakia", "Cote dIvoire", "Kenya", "Moldova", "Brunei", "Kazakhstan", "Mongolia", "Sint Maarten (Dutch part)", "Croatia", "Venezuela", "Tajikistan", "Antigua and Barbuda", "Jordan", "Montenegro", "Singapore", "Cuba", "Mozambique", "Seychelles", "Italy", "Czechia", "Morocco", "Jamaica", "Israel", "Argentina", "Vanuatu", "Cyprus", "Sierra Leone", "Montserrat", "Japan", "Brazil", "Tanzania", "Hungary", "Bhutan", "Nicaragua", "Guatemala", "Oceania", "Belize", "Grenada", "Oman", "Poland", "Finland", "Greenland", "Turkey", "Uganda", "Bangladesh", "France", "Greece", "Pakistan", "Belgium", "Philippines", "French Polynesia", "Papua New Guinea", "Georgia", "Belarus", "Gambia", "Paraguay", "Panama", "Fiji", "Germany", "Turks and Caicos Islands", "Gabon", "Turkmenistan", "Peru", "Palestine", "Ghana", "Barbados", "Bahrain", "Portugal", "Ukraine", "Haiti", "Eritrea", "Azerbaijan", "Bermuda", "Saint Lucia", "Niger", "Nigeria", "Honduras", "Equatorial Guinea", "Saint Pierre and Miquelon", "El Salvador", "Hong Kong", "Tonga", "Austria", "United Kingdom", "Costa Rica", "Trinidad and Tobago", "Guyana", "Ethiopia", "Qatar", "Norway", "Guinea", "Tunisia", "North Macedonia", "Russia", "Guinea-Bissau", "Bahamas", "Eswatini", "Romania", "United Arab Emirates", "Estonia", "North Korea", "Benin", "Slovenia", "Myanmar", "Micronesia", "Liechtenstein", "Comoros", "Switzerland", "Burundi", "Yemen", "Algeria", "Chile", "Canada", "Spain", "Solomon Islands", "Congo", "Angola", "Malaysia", "Liberia", "Mexico", "Macao", "Kyrgyzstan", "Mauritius", "Lesotho", "Laos", "Colombia", "Sudan", "Madagascar", "Malta", "Andorra", "Lebanon", "Zambia", "Latvia", "Mauritania", "China", "Central African Republic", "Burkina Faso", "Lithuania", "South Korea", "Somalia", "Syria", "Mali", "Luxembourg", "Cambodia", "South Africa", "Zimbabwe", "Vietnam", "Sweden", "Albania", "Kiribati", "Libya", "Malawi", "Bulgaria", "Taiwan", "Sri Lanka", "Cook Islands", "Chad", "Cameroon", "Kuwait", "Suriname"], "locationmode": "country names", "locations": ["Afghanistan", "Armenia", "Serbia", "Denmark", "Ireland", "Senegal", "Djibouti", "Iraq", "Namibia", "Bosnia and Herzegovina", "Thailand", "Aruba", "Saudi Arabia", "Dominica", "Iran", "Nepal", "Sao Tome and Principe", "Dominican Republic", "United States", "Saint Vincent and the Grenadines", "New Zealand", "Iceland", "Ecuador", "Samoa", "Uzbekistan", "New Caledonia", "India", "Togo", "Bolivia", "Netherlands", "Indonesia", "Uruguay", "Australia", "Egypt", "Democratic Republic of Congo", "Botswana", "Anguilla", "Slovakia", "Cote dIvoire", "Kenya", "Moldova", "Brunei", "Kazakhstan", "Mongolia", "Sint Maarten (Dutch part)", "Croatia", "Venezuela", "Tajikistan", "Antigua and Barbuda", "Jordan", "Montenegro", "Singapore", "Cuba", "Mozambique", "Seychelles", "Italy", "Czechia", "Morocco", "Jamaica", "Israel", "Argentina", "Vanuatu", "Cyprus", "Sierra Leone", "Montserrat", "Japan", "Brazil", "Tanzania", "Hungary", "Bhutan", "Nicaragua", "Guatemala", "Oceania", "Belize", "Grenada", "Oman", "Poland", "Finland", "Greenland", "Turkey", "Uganda", "Bangladesh", "France", "Greece", "Pakistan", "Belgium", "Philippines", "French Polynesia", "Papua New Guinea", "Georgia", "Belarus", "Gambia", "Paraguay", "Panama", "Fiji", "Germany", "Turks and Caicos Islands", "Gabon", "Turkm ...
