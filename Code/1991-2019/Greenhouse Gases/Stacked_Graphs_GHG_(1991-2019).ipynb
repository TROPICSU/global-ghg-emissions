# %% [markdown]
# # Loading the gdrive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# # Importing the Libraries

# %%
import numpy as np                    # Mathematical Calculations
import pandas as pd                   # Manipulation of raw data
import matplotlib.pyplot as plt       # Plotting the graphs
import seaborn as sns
import plotly.express as px           # For creating interactive publication quality graphs
import plotly.graph_objects as go
# %matplotlib inline

# %% [markdown]
# # Creating Stacked Area Charts for the top CO2 emitters

# %%
data_1 = pd.read_excel('/gdrive/My Drive/TROP-ICSU-Internship-Sahil-Ashutosh/Assignment-1-Emissions/Analysis/Data/1991-2019/GHG/Top_CO2_(1991-2019).xlsx')

# %%
data_1.head()
# Out:
#   country  year       co2
# 0   China  1991  2538.030
# 1   China  1992  2653.192
# 2   China  1993  2835.795
# 3   China  1994  3010.242
# 4   China  1995  3265.057

# %%
fig = px.area(data_1, x= "year", y= "co2",
            color= "country",
            title = 'CO2 emissions measured in Million Tonnes Per Year')
 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="383d83e9-9a98-4a72-a916-f81405eef069" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("383d83e9-9a98-4a72-a916-f81405eef069")) {
#                     Plotly.newPlot(
#                         '383d83e9-9a98-4a72-a916-f81405eef069',
# ...

# %% [markdown]
# # Creating Stacked Area Charts for the top methane emitters

# %%
data_2 = pd.read_excel('/gdrive/My Drive/TROP-ICSU-Internship-Sahil-Ashutosh/Assignment-1-Emissions/Analysis/Data/1991-2019/GHG/Top_Methane_(1991-2019).xlsx')

# %%
fig = px.area(data_2, x= "year", y= "methane", color= "country",
              title = 'Methane emissions measured in Million Tonnes of Carbon Equivalents')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5d546dbd-4653-4dec-90a3-863f902e6026" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5d546dbd-4653-4dec-90a3-863f902e6026")) {
#                     Plotly.newPlot(
#                         '5d546dbd-4653-4dec-90a3-863f902e6026',
# ...

# %% [markdown]
# # Creating Stacked Area Charts for the top Nitrous Oxide Emitters

# %%
data_3 = pd.read_excel('/gdrive/My Drive/TROP-ICSU-Internship-Sahil-Ashutosh/Assignment-1-Emissions/Analysis/Data/1991-2019/GHG/Top_N2O_(1991-2019).xlsx')

# %%
fig = px.area(data_3, x= "year", y= "nitrous_oxide", color= "country",
              title = 'Nitrous Oxide emissions measured in Million Tonnes of Carbon Equivalents')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f4cbcb17-733b-41ad-a030-eecc3a0411d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f4cbcb17-733b-41ad-a030-eecc3a0411d4")) {
#                     Plotly.newPlot(
#                         'f4cbcb17-733b-41ad-a030-eecc3a0411d4',
# ...
