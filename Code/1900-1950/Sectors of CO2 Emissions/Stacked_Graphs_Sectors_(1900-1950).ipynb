# %% [markdown]
# # Loading the gdrive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# # Importing the Libraries

# %%
import numpy as np                    # Mathematical Calculations
import pandas as pd                   # Manipulation of raw data
import matplotlib.pyplot as plt       # Plotting the graphs
import seaborn as sns
import plotly.express as px           # For creating interactive publication quality graphs
import plotly.graph_objects as go
# %matplotlib inline

# %% [markdown]
# # Importing the Data

# %%
data_1 = pd.read_excel('/gdrive/My Drive/TROP-ICSU-Internship-Sahil-Ashutosh/Assignment-1-Emissions/Analysis/Data/1900-1950/Sectors/Top_Cement_(1900-1950).xlsx')

# %%
data_1.head()
# Out:
#           country  year  cement_co2  longitude  latitude
# 0  United Kingdom  1900       6.819         -3        55
# 1  United Kingdom  1901       6.653         -3        55
# 2  United Kingdom  1902       6.487         -3        55
# 3  United Kingdom  1903       6.321         -3        55
# 4  United Kingdom  1904       6.155         -3        55

# %% [markdown]
# # Creating Stacked Area Charts for the top cement emitter countries

# %%
fig = px.area(data_1, x= "year", y= "cement_co2",
            color= "country",
            title = 'CO2 emissions from Cement Production measured in Million Tonnes Per Year')
 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="71337401-3530-4acf-ae01-84fff859071a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("71337401-3530-4acf-ae01-84fff859071a")) {
#                     Plotly.newPlot(
#                         '71337401-3530-4acf-ae01-84fff859071a',
# ...

# %% [markdown]
# # Creating Stacked Area Charts for the top CO2 emitter countries from coal production

# %%
data_2 = pd.read_excel('/gdrive/My Drive/TROP-ICSU-Internship-Sahil-Ashutosh/Assignment-1-Emissions/Analysis/Data/1900-1950/Sectors/Top_Coal_(1900-1950).xlsx')

# %%
fig = px.area(data_2, x= "year", y= "coal_co2", color= "country",
              title = 'CO2 emissions from Coal Production measured in Million Tonnes Per Year')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1ffcbe83-06b1-4c18-af95-e28f3cf68810" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1ffcbe83-06b1-4c18-af95-e28f3cf68810")) {
#                     Plotly.newPlot(
#                         '1ffcbe83-06b1-4c18-af95-e28f3cf68810',
# ...

# %% [markdown]
# # Creating Stacked Area Charts for the top CO2 emitter countries from gas flaring

# %%
data_3 = pd.read_excel('/gdrive/My Drive/TROP-ICSU-Internship-Sahil-Ashutosh/Assignment-1-Emissions/Analysis/Data/1900-1950/Sectors/Top_Flaring_(1900-1950).xlsx')

# %%
fig = px.area(data_3, x= "year", y= "flaring_co2", color= "country",
              title = 'CO2 emissions from Gas Flaring measured in Million Tonnes Per Year')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="18fb47c4-ca39-434e-a492-cd1049958d21" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("18fb47c4-ca39-434e-a492-cd1049958d21")) {
#                     Plotly.newPlot(
#                         '18fb47c4-ca39-434e-a492-cd1049958d21',
# ...

# %% [markdown]
# # Creating Stacked Area Charts for the top CO2 emitter countries from gas production

# %%
data_4 = pd.read_excel('/gdrive/My Drive/TROP-ICSU-Internship-Sahil-Ashutosh/Assignment-1-Emissions/Analysis/Data/1900-1950/Sectors/Top_Gas_(1900-1950).xlsx')

# %%
fig = px.area(data_4, x= "year", y= "gas_co2", color= "country",
              title = 'CO2 emissions from Gas Production measured in Million Tonnes Per Year')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ed0b4f94-5556-4f05-a73b-83abfb5913ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ed0b4f94-5556-4f05-a73b-83abfb5913ae")) {
#                     Plotly.newPlot(
#                         'ed0b4f94-5556-4f05-a73b-83abfb5913ae',
# ...

# %% [markdown]
# # Creating Stacked Area Charts for the top CO2 emitter countries from gas production

# %%
data_5 =  pd.read_excel('/gdrive/My Drive/TROP-ICSU-Internship-Sahil-Ashutosh/Assignment-1-Emissions/Analysis/Data/1900-1950/Sectors/Top_Oil_(1900-1950).xlsx')

# %%
fig = px.area(data_5, x= "year", y= "oil_co2", color= "country",
              title = 'CO2 emissions from Oil Production measured in Million Tonnes Per Year')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="049a4179-5d04-4245-8162-89b965ec4757" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("049a4179-5d04-4245-8162-89b965ec4757")) {
#                     Plotly.newPlot(
#                         '049a4179-5d04-4245-8162-89b965ec4757',
# ...
