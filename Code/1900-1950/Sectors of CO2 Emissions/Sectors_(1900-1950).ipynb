# %% [markdown]
# # Loading the gdrive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# # Importing the Libraries

# %%
import numpy as np                    # Mathematical Calculations
import pandas as pd                   # Manipulation of raw data
import matplotlib.pyplot as plt       # Plotting the graphs
import seaborn as sns
import plotly.express as px           # For creating interactive publication quality graphs
# %matplotlib inline

# %% [markdown]
# # Importing the Dataset

# %%
data = pd.read_csv('/gdrive/My Drive/TROP-ICSU-Internship-Sahil-Ashutosh/Assignment-1-Emissions/Analysis/Data/1900-1950/Sectors/Sources_(1900-1950).csv')

# %%
data.head()
# Out:
#       country  year  cement_co2  ...  other_industry_co2  longitude  latitude
# 0   Argentina  1900       0.534  ...               1.379    -58.382   -34.604
# 1     Armenia  1900       3.890  ...               1.379     45.038    40.069
# 2   Australia  1900       0.327  ...               1.379    151.210   -33.865
# 3     Austria  1900       2.849  ...               3.868     14.550    47.516
# 4  Azerbaijan  1900       1.765  ...               1.183     48.500    41.400
#
# [5 rows x 10 columns]

# %%
data.tail()
# Out:
#             country  year  cement_co2  ...  other_industry_co2  longitude  latitude
# 3499  United States  1950      19.723  ...              14.813     -100.0      40.0
# 3500     Uzbekistan  1950       0.660  ...              27.588       63.0      42.0
# 3501      Venezuela  1950       0.247  ...              27.588      -65.0       7.0
# 3502        Vietnam  1950       0.073  ...              27.588      108.0      16.0
# 3503       Zimbabwe  1950       0.044  ...              27.588       30.0     -20.0
#
# [5 rows x 10 columns]

# %%
data = data.round(4)

# %%
data.drop('other_industry_co2', axis = 1, inplace = True)

# %% [markdown]
# # Normalizing the data into the scale of 0 and +1 by using min-max scaler function

# %%
from sklearn.preprocessing import MinMaxScaler
# Storing the MinMaxScaler in the variable scalerr
scaler = MinMaxScaler()

# %%
# Performing the scaling on the cement_co2 attribute
scaler.fit(data[['cement_co2']])
data[['cement_co2']]=scaler.transform(data[['cement_co2']])
data.head()
# Out:
#       country  year  cement_co2  ...  oil_co2  longitude  latitude
# 0   Argentina  1900    0.003838  ...    0.438    -58.382   -34.604
# 1     Armenia  1900    0.028003  ...    0.329     45.038    40.069
# 2   Australia  1900    0.002347  ...    0.121    151.210   -33.865
# 3     Austria  1900    0.020507  ...  135.311     14.550    47.516
# 4  Azerbaijan  1900    0.012702  ...    1.059     48.500    41.400
#
# [5 rows x 9 columns]

# %%
# Performing the scaling on the coal_co2 attribute
scaler.fit(data[['coal_co2']])
data[['coal_co2']]=scaler.transform(data[['coal_co2']])
data.head()
# Out:
#       country  year  cement_co2  ...  oil_co2  longitude  latitude
# 0   Argentina  1900    0.003838  ...    0.438    -58.382   -34.604
# 1     Armenia  1900    0.028003  ...    0.329     45.038    40.069
# 2   Australia  1900    0.002347  ...    0.121    151.210   -33.865
# 3     Austria  1900    0.020507  ...  135.311     14.550    47.516
# 4  Azerbaijan  1900    0.012702  ...    1.059     48.500    41.400
#
# [5 rows x 9 columns]

# %%
# Performing the scaling on the flaring_co2 attribute
scaler.fit(data[['flaring_co2']])
data[['flaring_co2']]=scaler.transform(data[['flaring_co2']])
data.head()
# Out:
#       country  year  cement_co2  ...  oil_co2  longitude  latitude
# 0   Argentina  1900    0.003838  ...    0.438    -58.382   -34.604
# 1     Armenia  1900    0.028003  ...    0.329     45.038    40.069
# 2   Australia  1900    0.002347  ...    0.121    151.210   -33.865
# 3     Austria  1900    0.020507  ...  135.311     14.550    47.516
# 4  Azerbaijan  1900    0.012702  ...    1.059     48.500    41.400
#
# [5 rows x 9 columns]

# %%
# Performing the scaling on the gas_co2 attribute
scaler.fit(data[['gas_co2']])
data[['gas_co2']]=scaler.transform(data[['gas_co2']])
data.head()
# Out:
#       country  year  cement_co2  ...  oil_co2  longitude  latitude
# 0   Argentina  1900    0.003838  ...    0.438    -58.382   -34.604
# 1     Armenia  1900    0.028003  ...    0.329     45.038    40.069
# 2   Australia  1900    0.002347  ...    0.121    151.210   -33.865
# 3     Austria  1900    0.020507  ...  135.311     14.550    47.516
# 4  Azerbaijan  1900    0.012702  ...    1.059     48.500    41.400
#
# [5 rows x 9 columns]

# %%
# Performing the scaling on the oil_co2 attribute
scaler.fit(data[['oil_co2']])
data[['oil_co2']]=scaler.transform(data[['oil_co2']])
data.head()
# Out:
#       country  year  cement_co2  ...   oil_co2  longitude  latitude
# 0   Argentina  1900    0.003838  ...  0.001814    -58.382   -34.604
# 1     Armenia  1900    0.028003  ...  0.001693     45.038    40.069
# 2   Australia  1900    0.002347  ...  0.001461    151.210   -33.865
# 3     Austria  1900    0.020507  ...  0.152008     14.550    47.516
# 4  Azerbaijan  1900    0.012702  ...  0.002506     48.500    41.400
#
# [5 rows x 9 columns]

# %% [markdown]
# # Creating some interactive graphs and maps for CO2 emissions from Cement Production

# %%
# Showing the top 5 countries emitting the highest amount of CO2 from Cement Production

top_cement = data.groupby('country')['cement_co2'].sum().reset_index().sort_values(by=['cement_co2'], ascending=False).head(5)['country'].tolist()

fig = px.line(
    data[data['country'].isin(top_cement)],
    x='year',
    y='cement_co2',
    color='country',
    title = 'Top 5 countries with highest CO2 emissions from Cement Production measured in Million Tonnes Per Year '
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bc337235-5b5b-4525-8aa5-a0118b537743" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bc337235-5b5b-4525-8aa5-a0118b537743")) {
#                     Plotly.newPlot(
#                         'bc337235-5b5b-4525-8aa5-a0118b537743',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Indonesia<br>year=%{x}<br>cement_co2=%{y}", "legendgroup": "country=Indonesia", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "country=Indonesia", "showlegend": true, "type": "scatter", "x": [1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950], "xaxis": "x", "y": [1.0, 0.9655306494235909, 0.9310684994635543, 0.8966063495035177, 0.8621369989271083, 0.8276748489670717, 0.7932054983906625, 0.7587433484306259, 0.7242811984705892, 0.6898118478941798, 0.6553496979341432, 0.6208875479741066, 0.5864181973976974, 0.5519560474376608, 0.5174938974776242, 0.4830245469012147, 0.4485623969411782, 0.41409304636476885, 0.37963089640473224, 0.3451687464446957, 0.3106993958682863, 0.2762372459082497, 0.2417750959482132, 0.20730574537180385, 0.17284359541176725, 0.1383742448353579, 0.10391209487532134, 0.06944994491528476, 0.03498059433887541, 0.0005184443788388286, 0.0004896419133477827, 0.0004608394478567366, 0.0002808240385376989, 0.00025202157304665283, 0.00038883328412912154, 0.0004896419133477827, 0.0004608394478567366, 0.0005040431460933057, 0.0005544474607026362, 0.0005976511589392053, 0.0005976511589392053, 0.0005976511589392053, 0.0005040431460933057, 0.0004032345168746445, 0.00030962650402874487, 0.00021601849118284527, 0.00011520986196418417, 2.1601849118284527e-05, 0.00012241047833694564, 0.00020161725843732226, 0.0002808240385376989], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Turkmenistan<br>year=%{x}<br>cement_co2=%{y}", "legendgroup": "country=Turkmenistan", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "country=Turkmenistan", "showlegend": true, "type": "scatter", "x": [1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950], "xaxis": "x", "y": [0.21151090533349656, 0.2039646593748425, 0.19641841341618843, 0.18887216745753438, 0.1813259214988803, 0.17377967554022627, 0.1662334295815722, 0.15868718362291814, 0.15114093766426406, 0.14359469170561, 0.13604844574695593, 0.12850219978830188, 0.12095595382964783, 0.11340970787099378, 0.10586346191233971, 0.09831721595368564, 0.09077096999503158, 0.08322472403637753, 0.07567847807772346, 0.0681322321190694, 0.06058598616041533, 0.053039740201761276, 0.04549349424310721, 0.03794724828445315, 0.030401002325799092, 0.02285475636714503, 0.015308510408490968, 0.007762264449836906, 0.00021601849118284527, 0.00023762034030112982, 0.00025202157304665283, 0.00026642280579217587, 0.0003240277367742679, 0.00026642280579217587, 0.00036723143501083696, 0.0004968425297205442, 0.0006696573226668204, 0.0006120523916847282, 0.0006408548571757743, 0.0006408548571757743, 0.0007200616372761509, 0.0006840585554123434, 0.0005760493098209208, 0.00046804006422949816, 0.000352830202265314, 0.00024482095667389134, 0.0004608394478567366, 0.0006480554735485358, 0.0008640739647313811, 0.0010440893740504187, 0.0013465152617064022], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=United Kingdom<br>year=%{x}<br>cement_co2=%{y}", "legendgroup": "country=United Kingdom", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "country=United Kingdom", "showlegend": true, "type": "scatter", "x": [1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 19 ...

# %% [markdown]
# For the above graph we have only considered the emissions of United Kingdom and The United States because the emissions for Indonesia, Turkmenistan and Iran were almost very high during the statrting period and after 1930 the emissions have came down to zero.
#
# This could be because of the fact that there were a lot of missing values for these nations and while filling these missing values using the interpolate, median and mean method this discrepancy could have been created or arised.

# %%
# Showing the bottom 5 countries emitting the lowest amount of CO2 from Cement Production

bottom_cement = data.groupby('country')['cement_co2'].sum().reset_index().sort_values(by=['cement_co2'], ascending=True).head(5)['country'].tolist()

plt.figure(figsize=(10,10))
g = sns.barplot(
    data = data[data['country'].isin(bottom_cement)],
    x ='country',
    y ='cement_co2',
    order = bottom_cement,
    ci=None
)
plt.title('Bottom 5 countries with lowest CO2 emissions from Cement Production measured in Million Tonnes Per Year')
plt.show()

# %%
# Creating a time series chloropleth map for CO2 emissions from cement productions
fig = px.choropleth(
    data.groupby(['country', 'year'])['cement_co2'].sum().reset_index().sort_values(by=['year'], ascending=True),
    locations='country',
    locationmode='country names',
    color='cement_co2',
    color_continuous_scale='Spectral_r', # (_r) is used for inverting the color ramp
    height=750,
    animation_frame='year',
    animation_group='country'
)

fig.update_layout(
    title='CO2 Emissions from Cement Production in Million Tonnes Per Year'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7db87aa3-3e88-4df7-931c-ff67fdf89ddd" class="plotly-graph-div" style="height:750px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7db87aa3-3e88-4df7-931c-ff67fdf89ddd")) {
#                     Plotly.newPlot(
#                         '7db87aa3-3e88-4df7-931c-ff67fdf89ddd',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "year=1900<br>country=%{location}<br>cement_co2=%{z}", "ids": ["Argentina", "Japan", "Kazakhstan", "Kyrgyzstan", "Latvia", "Lithuania", "Malaysia", "Mexico", "Montenegro", "Netherlands", "Armenia", "New Zealand", "North Macedonia", "Norway", "Oceania", "Peru", "Italy", "Indonesia", "Hungary", "Greece", "Azerbaijan", "Belarus", "Belgium", "Bosnia and Herzegovina", "Australia", "Bulgaria", "Canada", "Poland", "Chile", "Czechia", "Denmark", "Estonia", "Finland", "France", "Georgia", "Germany", "Croatia", "Portugal", "Moldova", "Austria", "Taiwan", "Turkey", "Switzerland", "Turkmenistan", "Sweden", "Ukraine", "Spain", "South Africa", "Slovenia", "United States", "Slovakia", "United Kingdom", "Tajikistan", "Uzbekistan", "Serbia", "Romania", "Vietnam", "Russia"], "locationmode": "country names", "locations": ["Argentina", "Japan", "Kazakhstan", "Kyrgyzstan", "Latvia", "Lithuania", "Malaysia", "Mexico", "Montenegro", "Netherlands", "Armenia", "New Zealand", "North Macedonia", "Norway", "Oceania", "Peru", "Italy", "Indonesia", "Hungary", "Greece", "Azerbaijan", "Belarus", "Belgium", "Bosnia and Herzegovina", "Australia", "Bulgaria", "Canada", "Poland", "Chile", "Czechia", "Denmark", "Estonia", "Finland", "France", "Georgia", "Germany", "Croatia", "Portugal", "Moldova", "Austria", "Taiwan", "Turkey", "Switzerland", "Turkmenistan", "Sweden", "Ukraine", "Spain", "South Africa", "Slovenia", "United States", "Slovakia", "United Kingdom", "Tajikistan", "Uzbekistan", "Serbia", "Romania", "Vietnam", "Russia"], "name": "", "type": "choropleth", "z": [0.0038379285266818843, 0.002786638536258704, 0.011657797907500884, 0.009706430870482514, 0.00529965365035247, 0.005767693714581969, 0.0008424721156130965, 0.0008568733483586196, 0.0013465152617064022, 0.005861301727427868, 0.028003197073669512, 0.0002880246549104604, 0.018044744630140344, 0.0024698114158571973, 0.0051844437883882865, 0.00243380833399339, 0.016107778825867496, 1.0, 0.005076434542796863, 0.010772122093651219, 0.012701887281551302, 0.0005040431460933057, 0.015373315955845823, 0.0023690027866385367, 0.002347400937520252, 0.023092376707446162, 0.007222218221879794, 0.06665610576265328, 0.0005400462279571132, 0.005954909740273768, 0.0006480554735485358, 0.0005400462279571132, 0.0006120523916847282, 0.004702002491413265, 0.00020881787481008375, 0.005738891249090923, 0.003621910035499039, 0.05321975561108031, 0.06613766138381447, 0.02050735542962478, 0.004918020982596111, 0.0249933394298552, 0.011240162157880717, 0.21151090533349656, 0.0004536388314839751, 0.0026138237433124276, 0.04990027146323726, 0.0006192530080574897, 0.009375202517335484, 0.009972853676274691, 0.0013321140289608792, 0.049093802429487965, 0.032165153337125656, 0.0020593762826097914, 0.012428263859386366, 0.015812553554584274, 0.02194027808780432, 0.024503697516507415]}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "cement_co2"}}, "colorscale": [[0.0, "rgb(94,79,162)"], [0.1, "rgb(50,136,189)"], [0.2, "rgb(102,194,165)"], [0.3, "rgb(171,221,164)"], [0.4, "rgb(230,245,152)"], [0.5, "rgb(255,255,191)"], [0.6, "rgb(254,224,139)"], [0.7, "rgb(253,174,97)"], [0.8, "rgb(244,109,67)"], [0.9, "rgb(213,62,79)"], [1.0, "rgb(158,1,66)"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}}, "height": 750, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "sliders": [{"active": 0, "currentvalue": {"prefix": "year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1900"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1900", "method": "animate"}, {"args": [["1901"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1901", "method": "animate"}, {"args": [["1902"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1902", "method": "animate"}, {"args": [["1903"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1903", "method": "animate"}, {"args": [["1904"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1904", "method": "animate"}, {"args": [["1905"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1905", "method": "animate"}, {"args": [["1906"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1906", "method": "animate"}, {"args": [["1907"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1907", "method": "animate"}, {"args": [["1908"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1908", "method": "animate"}, {"args": [["1909"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1909", "method": "animate"}, {"args": [["1910"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1910", "method": "animate"}, {"args": [["1911"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1911", "method": "animate"}, {"args": [["1912"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1912", "method": "animate"}, {"args": [["1913"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1913", "method": "animate"}, {"args": [["1914"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1914", "method": "animate"}, {"args": [["1915"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1915", "method": "animate"}, {"args": [["1916"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1916", "method": "animate"}, {"args": [[" ...

# %% [markdown]
# # Creating some interactive graphs and maps for CO2 emissions from coal production

# %%
# Showing the top 5 countries emitting the highest amount of CO2 from Coal Production

top_coal = data.groupby('country')['coal_co2'].sum().reset_index().sort_values(by=['coal_co2'], ascending=False).head(5)['country'].tolist()

fig = px.line(
    data[data['country'].isin(top_coal)],
    x='year',
    y='coal_co2',
    color='country',
    title = 'Top 5 countries with highest CO2 emissions from Coal Production measured in Million Tonnes Per Year '
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ecefc234-dff4-4046-8d5e-9ff20ead41bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ecefc234-dff4-4046-8d5e-9ff20ead41bf")) {
#                     Plotly.newPlot(
#                         'ecefc234-dff4-4046-8d5e-9ff20ead41bf',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "country=France<br>year=%{x}<br>coal_co2=%{y}", "legendgroup": "country=France", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "country=France", "showlegend": true, "type": "scatter", "x": [1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950], "xaxis": "x", "y": [0.08286770655036474, 0.08013293491540067, 0.07543895276684492, 0.08302887885322684, 0.08094266456497985, 0.0818639254481396, 0.0877673445573725, 0.09359662440728886, 0.09432705728385989, 0.09651642184593864, 0.09686133057406353, 0.10092867480909143, 0.10201562081959341, 0.11013870488384314, 0.07629896817491709, 0.06655255667624031, 0.07071467022535112, 0.0783961421797587, 0.06981275001853483, 0.07478008039274468, 0.09768073056181442, 0.08871890583347035, 0.10466593816785774, 0.11761774442585592, 0.13109110425591583, 0.12894880200627282, 0.13370145087307037, 0.13722080927836713, 0.1348373932636424, 0.14887807959977695, 0.15076057209720625, 0.1377733079325784, 0.12022035477247309, 0.12192104491227392, 0.1213305095945872, 0.11504543447217684, 0.1152794566559326, 0.1280249623662673, 0.11748751720514335, 0.11414738240062923, 0.08210052638874116, 0.07623063111850356, 0.07805896972217119, 0.07962943264125948, 0.05090337075754207, 0.06790640402028193, 0.10108017677378178, 0.10827748713039163, 0.11128496230179838, 0.1262133856820973, 0.10756639493016405], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Germany<br>year=%{x}<br>coal_co2=%{y}", "legendgroup": "country=Germany", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "country=Germany", "showlegend": true, "type": "scatter", "x": [1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950], "xaxis": "x", "y": [0.2087039490437647, 0.20796255645059908, 0.20382171764546608, 0.21945156288782083, 0.22747149667823882, 0.24442682293933152, 0.23125517766022946, 0.2828399849142725, 0.28558442688740826, 0.2850390198145229, 0.28484045553739684, 0.29342191363098635, 0.3192997385785248, 0.3426774587640663, 0.32079026003539346, 0.29823387390523715, 0.3226089283008894, 0.33800990887317994, 0.324474658878821, 0.2496965125537107, 0.27663678532171604, 0.30497796774619873, 0.2935476280272188, 0.21388918437144414, 0.2911500288498422, 0.29515354885293676, 0.266219897043133, 0.310214778210794, 0.3231169433995107, 0.3453419592749825, 0.2960986632369201, 0.2476038513733492, 0.22309856975698442, 0.23404474787816665, 0.2611552185979944, 0.28794463409052085, 0.31747333404249145, 0.35835501100806827, 0.38143552946713216, 0.4122117030432555, 0.4163054795359527, 0.42059008403523873, 0.42677716639750896, 0.43371208824505925, 0.38547708613370213, 0.07366025523245882, 0.1729314340789164, 0.20259551876529125, 0.2351884265392761, 0.27165269302800854, 0.3203460691687055], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Russia<br>year=%{x}<br>coal_co2=%{y}", "legendgroup": "country=Russia", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "country=Russia", "showlegend": true, "type": "scatter", "x": [1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950], "xaxis": "x", "y": [0.018398140716314185, 0.01781856511522208, 0.01747 ...

# %%
# Showing the bottom 5 countries emitting the lowest amount of CO2 from Coal Production

bottom_coal = data.groupby('country')['coal_co2'].sum().reset_index().sort_values(by=['coal_co2'], ascending=True).head(5)['country'].tolist()

plt.figure(figsize=(15, 15))
g = sns.barplot(
    data = data[data['country'].isin(bottom_coal)],
    x ='country',
    y ='cement_co2',
    order = bottom_coal,
    ci=None
)

#g.set(ylim=(0,0.004))
plt.title('Bottom 5 countries with lowest CO2 emissions from Cement Production measured in Million Tonnes Per Year')
plt.show()

# %%
# Creating a time series chloropleth map for CO2 emissions from coal productions
fig = px.choropleth(
    data.groupby(['country', 'year'])['coal_co2'].sum().reset_index().sort_values(by=['year'], ascending=True),
    locations='country',
    locationmode='country names',
    color='coal_co2',
    color_continuous_scale='Spectral_r', # (_r) is used for inverting the color ramp
    height=750,
    animation_frame='year',
    animation_group='country'
)

fig.update_layout(
    title='CO2 Emissions from Coal Production in Million Tonnes Per Year'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="05b7647c-b7a4-45ae-be76-779840486b43" class="plotly-graph-div" style="height:750px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("05b7647c-b7a4-45ae-be76-779840486b43")) {
#                     Plotly.newPlot(
#                         '05b7647c-b7a4-45ae-be76-779840486b43',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "year=1900<br>country=%{location}<br>coal_co2=%{z}", "ids": ["Argentina", "Japan", "Kazakhstan", "Kyrgyzstan", "Latvia", "Lithuania", "Malaysia", "Mexico", "Montenegro", "Netherlands", "Armenia", "New Zealand", "North Macedonia", "Norway", "Oceania", "Peru", "Italy", "Indonesia", "Hungary", "Greece", "Azerbaijan", "Belarus", "Belgium", "Bosnia and Herzegovina", "Australia", "Bulgaria", "Canada", "Poland", "Chile", "Czechia", "Denmark", "Estonia", "Finland", "France", "Georgia", "Germany", "Croatia", "Portugal", "Moldova", "Austria", "Taiwan", "Turkey", "Switzerland", "Turkmenistan", "Sweden", "Ukraine", "Spain", "South Africa", "Slovenia", "United States", "Slovakia", "United Kingdom", "Tajikistan", "Uzbekistan", "Serbia", "Romania", "Vietnam", "Russia"], "locationmode": "country names", "locations": ["Argentina", "Japan", "Kazakhstan", "Kyrgyzstan", "Latvia", "Lithuania", "Malaysia", "Mexico", "Montenegro", "Netherlands", "Armenia", "New Zealand", "North Macedonia", "Norway", "Oceania", "Peru", "Italy", "Indonesia", "Hungary", "Greece", "Azerbaijan", "Belarus", "Belgium", "Bosnia and Herzegovina", "Australia", "Bulgaria", "Canada", "Poland", "Chile", "Czechia", "Denmark", "Estonia", "Finland", "France", "Georgia", "Germany", "Croatia", "Portugal", "Moldova", "Austria", "Taiwan", "Turkey", "Switzerland", "Turkmenistan", "Sweden", "Ukraine", "Spain", "South Africa", "Slovenia", "United States", "Slovakia", "United Kingdom", "Tajikistan", "Uzbekistan", "Serbia", "Romania", "Vietnam", "Russia"], "name": "", "type": "choropleth", "z": [0.0013338619784867209, 0.0118809774777824, 0.0025033282080541026, 0.00018567049289713663, 7.156050247077141e-05, 8.832242196842958e-05, 3.739197426400668e-05, 0.0006440445222369427, 7.091581325932301e-06, 0.00910043290880549, 3.158977136097116e-05, 0.0015723969867226257, 5.6087961396010016e-05, 0.002600031589771361, 0.008049589494144612, 8.187552985394567e-05, 0.008790982087310262, 0.0003468427957592344, 0.0061741885780412405, 0.00026883540117397906, 1.6117230286209777e-05, 0.00023402218375576596, 0.03201848968658434, 7.671801616235854e-05, 0.006476547818210537, 0.0001386081804614041, 0.01305495653182992, 0.04012481183133641, 0.000547341140519684, 0.021776312184303755, 0.0033182153713248686, 0.00036231533683399574, 0.0003487768633935796, 0.08286770655036474, 9.799276014015544e-05, 0.2087039490437647, 8.380959748829084e-05, 0.0015607925809165547, 0.00017664484393685917, 0.017854667711063192, 7.027112404787464e-05, 0.0006678980230605331, 0.003518713716085318, 6.124547508759715e-05, 0.005753851212176891, 0.006818233100278184, 0.007147024598116863, 0.0015014811734633028, 6.317954272194234e-05, 0.4039255126085093, 0.006952973145470897, 0.26863167938316135, 5.9956096664700367e-05, 0.000639531697756804, 0.0002243518455840401, 0.0003062273754379858, 0.0003300808762615762, 0.018398140716314185]}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "coal_co2"}}, "colorscale": [[0.0, "rgb(94,79,162)"], [0.1, "rgb(50,136,189)"], [0.2, "rgb(102,194,165)"], [0.3, "rgb(171,221,164)"], [0.4, "rgb(230,245,152)"], [0.5, "rgb(255,255,191)"], [0.6, "rgb(254,224,139)"], [0.7, "rgb(253,174,97)"], [0.8, "rgb(244,109,67)"], [0.9, "rgb(213,62,79)"], [1.0, "rgb(158,1,66)"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}}, "height": 750, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "sliders": [{"active": 0, "currentvalue": {"prefix": "year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1900"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1900", "method": "animate"}, {"args": [["1901"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1901", "method": "animate"}, {"args": [["1902"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1902", "method": "animate"}, {"args": [["1903"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1903", "method": "animate"}, {"args": [["1904"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1904", "method": "animate"}, {"args": [["1905"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1905", "method": "animate"}, {"args": [["1906"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1906", "method": "animate"}, {"args": [["1907"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1907", "method": "animate"}, {"args": [["1908"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1908", "method": "animate"}, {"args": [["1909"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1909", "method": "animate"}, {"args": [["1910"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1910", "method": "animate"}, {"args": [["1911"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1911", "method": "animate"}, {"args": [["1912"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1912", "method": "animate"}, {"args": [["1913"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1913", "method": "animate"}, {"args": [["1914"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1914", "method": "animate"}, {"args": [["1915"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1915", "method": "animate"}, {"args": [["1916"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1916", "method": "animate"}, {"args": [["19 ...

# %% [markdown]
# # Creating some interactive graphs and maps for CO2 emissions from gas flaring

# %%
# Showing the top 5 countries emitting the highest amount of CO2 from gas flaring

top_flaring = data.groupby('country')['flaring_co2'].sum().reset_index().sort_values(by=['flaring_co2'], ascending=False).head(5)['country'].tolist()

fig = px.line(
    data[data['country'].isin(top_flaring)],
    x='year',
    y='flaring_co2',
    color='country',
    title = 'Top 5 countries with highest CO2 emissions from gas flaring measured in Million Tonnes Per Year '
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cf126931-5d43-40b3-9ab8-622343db7d93" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cf126931-5d43-40b3-9ab8-622343db7d93")) {
#                     Plotly.newPlot(
#                         'cf126931-5d43-40b3-9ab8-622343db7d93',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "country=United States<br>year=%{x}<br>flaring_co2=%{y}", "legendgroup": "country=United States", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "country=United States", "showlegend": true, "type": "scatter", "x": [1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950], "xaxis": "x", "y": [0.12382012569864792, 0.14132980820519958, 0.1588626823442102, 0.17637236485076185, 0.19390523898977252, 0.2114381131287831, 0.22894779563533477, 0.24648066977434543, 0.263990352280897, 0.2815232264199077, 0.29905610055891835, 0.31656578306547, 0.3340986572044806, 0.35163153134349123, 0.3691412138500429, 0.3866740879890535, 0.4041837704956052, 0.42171664463461583, 0.4392495187736265, 0.4567592012801781, 0.4742920754191888, 0.4918017579257404, 0.509334632064751, 0.5268675062037617, 0.5443771887103133, 0.561910062849324, 0.5794197453558756, 0.5969526194948862, 0.6144854936338968, 0.6319951761404485, 0.6495280502794593, 0.6670377327860109, 0.6845706069250215, 0.7021034810640321, 0.7196131635705837, 0.7371460377095944, 0.754655720216146, 0.7721885943551566, 0.7897214684941672, 0.807231151000719, 0.8247640251397297, 0.8422968992787403, 0.8598065817852918, 0.8773394559243025, 0.8948491384308541, 0.9123820125698648, 0.9299148867088755, 0.947424569215427, 0.9649574433544377, 0.9824671258609894, 0.9999999999999999], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Uzbekistan<br>year=%{x}<br>flaring_co2=%{y}", "legendgroup": "country=Uzbekistan", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "country=Uzbekistan", "showlegend": true, "type": "scatter", "x": [1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950], "xaxis": "x", "y": [0.7593636216053249, 0.7492056865882789, 0.7390245599387741, 0.7288434332892693, 0.7186854982722234, 0.7085043716227185, 0.6983232449732136, 0.6881421183237089, 0.6779841833066629, 0.6678030566571581, 0.6576219300076532, 0.6474408033581485, 0.6372828683411025, 0.6271017416915976, 0.6169206150420928, 0.606762680025047, 0.5965815533755421, 0.5864004267260372, 0.5762193000765324, 0.5660613650594866, 0.5558802384099817, 0.5456991117604768, 0.5355411767434309, 0.5253600500939261, 0.5151789234444212, 0.5049977967949164, 0.49483986177787054, 0.48465873512836566, 0.47447760847886084, 0.46429648182935596, 0.45413854681231014, 0.44395742016280526, 0.43377629351330044, 0.4236183584962545, 0.41343723184674963, 0.4032561051972448, 0.39307497854774004, 0.3829170435306941, 0.37273591688118923, 0.3625547902316844, 0.35237366358217953, 0.3422157285651337, 0.33203460191562884, 0.321853475266124, 0.31169554024907814, 0.30151441359957326, 0.2913332869500684, 0.28115216030056356, 0.27099422528351774, 0.26081309863401286, 0.250631971984508], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Vietnam<br>year=%{x}<br>flaring_co2=%{y}", "legendgroup": "country=Vietnam", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "country=Vietnam", "showlegend": true, "type": "scatter", "x": [1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950], "xaxis": "x", "y": [0.7629815162689302, 0.7543542289941789, 0.7457501333518867, 0 ...

# %% [markdown]
# In the above graph while making the report we have only considered the emissions for all the countries except Ireland because after doing lots of research we found that Ireland was not in the top emitters and this could have occured because of the fact that there were a lot of missing values for these nations and while filling these missing values using the interpolate, median and mean method this discrepancy could have been created or arised.

# %%
# Showing the bottom 5 countries emitting the lowest amount of CO2 from gas flaring

bottom_flaring = data.groupby('country')['flaring_co2'].sum().reset_index().sort_values(by=['flaring_co2'], ascending=True).head(5)['country'].tolist()

plt.figure(figsize=(15, 15))
g = sns.barplot(
    data = data[data['country'].isin(bottom_flaring)],
    x ='country',
    y ='flaring_co2',
    order = bottom_flaring,
    ci=None
)

# g.set(ylim=(0,0.004))
plt.title('Bottom 5 countries with lowest CO2 emissions from gas flaring in Million Tonnes Per Year')
plt.show()

# %%
# Creating a time series chloropleth map for CO2 emissions from gas flaring
fig = px.choropleth(
    data.groupby(['country', 'year'])['flaring_co2'].sum().reset_index().sort_values(by=['year'], ascending=True),
    locations='country',
    locationmode='country names',
    color='flaring_co2',
    color_continuous_scale='Spectral_r', # (_r) is used for inverting the color ramp
    height=750,
    animation_frame='year',
    animation_group='country'
)

fig.update_layout(
    title='CO2 Emissions from gas flaring in Million Tonnes Per Year'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8c1950be-2ae5-465e-aec3-f0aecfecefde" class="plotly-graph-div" style="height:750px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8c1950be-2ae5-465e-aec3-f0aecfecefde")) {
#                     Plotly.newPlot(
#                         '8c1950be-2ae5-465e-aec3-f0aecfecefde',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "year=1900<br>country=%{location}<br>flaring_co2=%{z}", "ids": ["Argentina", "Japan", "Kazakhstan", "Kyrgyzstan", "Latvia", "Lithuania", "Malaysia", "Mexico", "Montenegro", "Netherlands", "Armenia", "New Zealand", "North Macedonia", "Norway", "Oceania", "Peru", "Italy", "Indonesia", "Hungary", "Greece", "Azerbaijan", "Belarus", "Belgium", "Bosnia and Herzegovina", "Australia", "Bulgaria", "Canada", "Poland", "Chile", "Czechia", "Denmark", "Estonia", "Finland", "France", "Georgia", "Germany", "Croatia", "Portugal", "Moldova", "Austria", "Taiwan", "Turkey", "Switzerland", "Turkmenistan", "Sweden", "Ukraine", "Spain", "South Africa", "Slovenia", "United States", "Slovakia", "United Kingdom", "Tajikistan", "Uzbekistan", "Serbia", "Romania", "Vietnam", "Russia"], "locationmode": "country names", "locations": ["Argentina", "Japan", "Kazakhstan", "Kyrgyzstan", "Latvia", "Lithuania", "Malaysia", "Mexico", "Montenegro", "Netherlands", "Armenia", "New Zealand", "North Macedonia", "Norway", "Oceania", "Peru", "Italy", "Indonesia", "Hungary", "Greece", "Azerbaijan", "Belarus", "Belgium", "Bosnia and Herzegovina", "Australia", "Bulgaria", "Canada", "Poland", "Chile", "Czechia", "Denmark", "Estonia", "Finland", "France", "Georgia", "Germany", "Croatia", "Portugal", "Moldova", "Austria", "Taiwan", "Turkey", "Switzerland", "Turkmenistan", "Sweden", "Ukraine", "Spain", "South Africa", "Slovenia", "United States", "Slovakia", "United Kingdom", "Tajikistan", "Uzbekistan", "Serbia", "Romania", "Vietnam", "Russia"], "name": "", "type": "choropleth", "z": [0.16424314107470026, 0.02683271875507317, 0.01686031679769939, 0.03518170644031633, 0.003432361603933301, 0.1229388436652056, 0.00364108629606438, 0.08063730605997356, 0.0015306477422945802, 0.0025278879380319585, 0.041257914144576635, 0.012848164382290871, 0.11825413390848583, 0.0015306477422945802, 0.04997796794916393, 0.03782555254064333, 0.04712539715670586, 0.03712980356687307, 0.0067023817806535395, 0.025603562234745702, 0.002898954057376099, 0.0009972401957373778, 0.0, 0.0017393724344256592, 0.006841531575407593, 0.01836777290753496, 0.027273359771794337, 0.05591502585867019, 0.07910665831767899, 0.008882395231800367, 0.0015306477422945802, 0.024397597346877246, 0.001878522229179712, 0.0037338528259004155, 0.01836777290753496, 0.004058535680326538, 0.001437881212458545, 0.11113430274357013, 0.06983000533407546, 0.39599712423757505, 0.04281175351933022, 0.006609615250817505, 0.018854797189174145, 0.004012152415408521, 0.00011595816229504396, 0.06157378417866833, 0.0019712887590157472, 0.002342354878359888, 0.00039425775180314943, 0.12382012569864792, 0.0006725573413112549, 0.03207402769080915, 0.017069041489830468, 0.7593636216053249, 0.002017672023933765, 0.03191168626359609, 0.7629815162689302, 0.016906700062617408]}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "flaring_co2"}}, "colorscale": [[0.0, "rgb(94,79,162)"], [0.1, "rgb(50,136,189)"], [0.2, "rgb(102,194,165)"], [0.3, "rgb(171,221,164)"], [0.4, "rgb(230,245,152)"], [0.5, "rgb(255,255,191)"], [0.6, "rgb(254,224,139)"], [0.7, "rgb(253,174,97)"], [0.8, "rgb(244,109,67)"], [0.9, "rgb(213,62,79)"], [1.0, "rgb(158,1,66)"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}}, "height": 750, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "sliders": [{"active": 0, "currentvalue": {"prefix": "year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1900"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1900", "method": "animate"}, {"args": [["1901"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1901", "method": "animate"}, {"args": [["1902"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1902", "method": "animate"}, {"args": [["1903"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1903", "method": "animate"}, {"args": [["1904"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1904", "method": "animate"}, {"args": [["1905"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1905", "method": "animate"}, {"args": [["1906"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1906", "method": "animate"}, {"args": [["1907"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1907", "method": "animate"}, {"args": [["1908"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1908", "method": "animate"}, {"args": [["1909"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1909", "method": "animate"}, {"args": [["1910"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1910", "method": "animate"}, {"args": [["1911"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1911", "method": "animate"}, {"args": [["1912"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1912", "method": "animate"}, {"args": [["1913"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1913", "method": "animate"}, {"args": [["1914"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1914", "method": "animate"}, {"args": [["1915"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1915", "method": "animate"}, {"args": [["1916"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1916", "method": "animate"}, {"args": [[ ...

# %% [markdown]
# # Creating some interactive graphs and maps for CO2 emissions from gas production

# %%
# Showing the top 5 countries emitting the highest amount of CO2 from gas production

top_gas = data.groupby('country')['gas_co2'].sum().reset_index().sort_values(by=['gas_co2'], ascending=False).head(5)['country'].tolist()

fig = px.line(
    data[data['country'].isin(top_gas)],
    x='year',
    y='gas_co2',
    color='country',
    title = 'Top 5 countries with highest CO2 emissions from Gas Production measured in Million Tonnes Per Year '
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d477d880-4f70-4ac7-b954-175d9c271dfe" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d477d880-4f70-4ac7-b954-175d9c271dfe")) {
#                     Plotly.newPlot(
#                         'd477d880-4f70-4ac7-b954-175d9c271dfe',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Austria<br>year=%{x}<br>gas_co2=%{y}", "legendgroup": "country=Austria", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "country=Austria", "showlegend": true, "type": "scatter", "x": [1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950], "xaxis": "x", "y": [0.24671463791315681, 0.2390051970590723, 0.231298888850601, 0.2235925806421297, 0.21588313978804521, 0.2081768315795739, 0.2004705233711026, 0.1927642151626313, 0.1850547743085468, 0.1773484661000755, 0.1696421578916042, 0.1619327170375197, 0.1542264088290484, 0.1465201006205771, 0.1388106597664926, 0.1311043515580213, 0.12339804334955, 0.1156917351410787, 0.1079822942869942, 0.1002759860785229, 0.0925696778700516, 0.0848602370159671, 0.0771539288074958, 0.0694476205990245, 0.06173817974493999, 0.0540318715364687, 0.04632556332799739, 0.038619255119526096, 0.030909814265441597, 0.023203506056970295, 0.015497197848498994, 0.007787756994414494, 8.14487859431926e-05, 9.397936839599146e-05, 0.00010650995084879034, 0.0001221731789147889, 0.00013470376136758775, 0.00014723434382038665, 0.0001597649262731855, 0.00017542815433918408, 0.00018795873679198293, 0.0002004893192447818, 0.00021301990169758067, 0.00022868312976357923, 0.0002412137122163781, 0.000253744294669177, 0.000253744294669177, 0.000297601333253973, 0.001331374385609879, 0.000297601333253973, 0.0029039624834361366], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Indonesia<br>year=%{x}<br>gas_co2=%{y}", "legendgroup": "country=Indonesia", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "country=Indonesia", "showlegend": true, "type": "scatter", "x": [1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950], "xaxis": "x", "y": [0.3848047891886135, 0.36650387351630076, 0.3481998251983748, 0.32989890952606205, 0.3115948612081361, 0.2932908128902102, 0.2749898972178974, 0.2566858488999715, 0.23838493322765875, 0.22008088490973285, 0.20177996923742011, 0.18347592091949416, 0.1651718726015682, 0.14687095692925548, 0.12856690861132952, 0.11026599293901679, 0.09196194462109086, 0.07365789630316492, 0.055356980630852176, 0.03705293231292624, 0.018752016640613496, 0.0004479683226875593, 0.00046989684197995736, 0.0010431709891955054, 0.0013188438031570802, 0.001917179115278226, 0.001732353024099443, 0.0016634348206090491, 0.002236708967824597, 0.002502983844946573, 0.002515514427399372, 0.003934602890178843, 0.004119428981357626, 0.004739692812771169, 0.005049824728477942, 0.005109344995128736, 0.004877529219751957, 0.005312966959986717, 0.00572647618092908, 0.005886241107202266, 0.0060961283632866466, 0.005247181402109524, 0.004398234440932401, 0.003549287479755278, 0.002697207872964955, 0.001848260911787832, 0.0009993139506107092, 0.00015036698943358636, 0.0022147804485321988, 0.003558685416594877, 0.0037309809253208617], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=United Kingdom<br>year=%{x}<br>gas_co2=%{y}", "legendgroup": "country=United Kingdom", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "country=United Kingdom", "showlegend": true, "type": "scatter", "x": [1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1 ...

# %% [markdown]
# Here, also we have not considered the emissions for Austria and Indoneasia because these nations were not in the top emitting countries and if we observe the individual graph for this nations then we could see that the emissions were very high for the first 30 years and after that the emissions had suddenly dropped to zero.
#
# This could be because of the fact that there were a lot of missing values for these nations and while filling these missing values using the interpolate, median and mean method this discrepancy could have been created or arised.

# %%
# Showing the bottom 5 countries emitting the lowest amount of CO2 from gas production

bottom_gas = data.groupby('country')['gas_co2'].sum().reset_index().sort_values(by=['gas_co2'], ascending=True).head(5)['country'].tolist()

plt.figure(figsize=(15, 15))
g = sns.barplot(
    data = data[data['country'].isin(bottom_gas)],
    x ='country',
    y ='gas_co2',
    order = bottom_gas,
    ci=None
)

# g.set(ylim=(0,0.004))
plt.title('Bottom 5 countries with lowest CO2 emissions from Gas Production in Million Tonnes Per Year')
plt.show()

# %%
# Creating a time series chloropleth map for CO2 emissions from gas production
fig = px.choropleth(
    data.groupby(['country', 'year'])['gas_co2'].sum().reset_index().sort_values(by=['year'], ascending=True),
    locations='country',
    locationmode='country names',
    color='gas_co2',
    color_continuous_scale='Spectral_r', # (_r) is used for inverting the color ramp
    height=750,
    animation_frame='year',
    animation_group='country'
)

fig.update_layout(
    title='CO2 Emissions from Gas Production in Million Tonnes Per Year'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="18eef69c-d9af-4bb7-869c-6b4227ec0803" class="plotly-graph-div" style="height:750px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("18eef69c-d9af-4bb7-869c-6b4227ec0803")) {
#                     Plotly.newPlot(
#                         '18eef69c-d9af-4bb7-869c-6b4227ec0803',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "year=1900<br>country=%{location}<br>gas_co2=%{z}", "ids": ["Argentina", "Japan", "Kazakhstan", "Kyrgyzstan", "Latvia", "Lithuania", "Malaysia", "Mexico", "Montenegro", "Netherlands", "Armenia", "New Zealand", "North Macedonia", "Norway", "Oceania", "Peru", "Italy", "Indonesia", "Hungary", "Greece", "Azerbaijan", "Belarus", "Belgium", "Bosnia and Herzegovina", "Australia", "Bulgaria", "Canada", "Poland", "Chile", "Czechia", "Denmark", "Estonia", "Finland", "France", "Georgia", "Germany", "Croatia", "Portugal", "Moldova", "Austria", "Taiwan", "Turkey", "Switzerland", "Turkmenistan", "Sweden", "Ukraine", "Spain", "South Africa", "Slovenia", "United States", "Slovakia", "United Kingdom", "Tajikistan", "Uzbekistan", "Serbia", "Romania", "Vietnam", "Russia"], "locationmode": "country names", "locations": ["Argentina", "Japan", "Kazakhstan", "Kyrgyzstan", "Latvia", "Lithuania", "Malaysia", "Mexico", "Montenegro", "Netherlands", "Armenia", "New Zealand", "North Macedonia", "Norway", "Oceania", "Peru", "Italy", "Indonesia", "Hungary", "Greece", "Azerbaijan", "Belarus", "Belgium", "Bosnia and Herzegovina", "Australia", "Bulgaria", "Canada", "Poland", "Chile", "Czechia", "Denmark", "Estonia", "Finland", "France", "Georgia", "Germany", "Croatia", "Portugal", "Moldova", "Austria", "Taiwan", "Turkey", "Switzerland", "Turkmenistan", "Sweden", "Ukraine", "Spain", "South Africa", "Slovenia", "United States", "Slovakia", "United Kingdom", "Tajikistan", "Uzbekistan", "Serbia", "Romania", "Vietnam", "Russia"], "name": "", "type": "choropleth", "z": [0.0005732741472155479, 0.0008301510874979247, 0.025339970365172503, 0.14147340853771237, 0.0004792947788195565, 0.00015036698943358636, 0.0005012232981119545, 0.001036905697969106, 0.004376305921640003, 0.00561683358446709, 0.28356081561561186, 0.11574499011650309, 0.04100006578555788, 0.0015945166171186553, 0.04147309527315104, 0.0024779226800409754, 0.04493466867573672, 0.3848047891886135, 0.018889853047594288, 0.00793499133823488, 0.052346508196567255, 0.0001378364069807875, 0.11507460395527837, 0.00639999498776702, 0.0060272101597962525, 0.01895563860547148, 0.0030230030167377256, 0.024368850225080587, 0.14856885085160973, 0.0, 1.5663228065998577e-05, 0.0032610840833409037, 0.00033519308061236955, 0.013401457933268383, 1.2530582452798862e-05, 0.013918344459446336, 0.0005450803366967505, 0.10865581309383214, 0.19098800509994707, 0.24671463791315681, 0.02181261140470962, 0.0385785307265545, 0.005967689893145459, 0.2622682233826934, 3.1326456131997154e-05, 0.026947017564743957, 0.05404440211892149, 0.008642969246818016, 0.02899576779577657, 0.036156995667551116, 0.015315504402933411, 0.42391900231502516, 0.12251463728662769, 0.00037905011919716556, 0.0001221731789147889, 0.28513027106782496, 0.10142253437295398, 0.06350185922517144]}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "gas_co2"}}, "colorscale": [[0.0, "rgb(94,79,162)"], [0.1, "rgb(50,136,189)"], [0.2, "rgb(102,194,165)"], [0.3, "rgb(171,221,164)"], [0.4, "rgb(230,245,152)"], [0.5, "rgb(255,255,191)"], [0.6, "rgb(254,224,139)"], [0.7, "rgb(253,174,97)"], [0.8, "rgb(244,109,67)"], [0.9, "rgb(213,62,79)"], [1.0, "rgb(158,1,66)"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}}, "height": 750, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "sliders": [{"active": 0, "currentvalue": {"prefix": "year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1900"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1900", "method": "animate"}, {"args": [["1901"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1901", "method": "animate"}, {"args": [["1902"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1902", "method": "animate"}, {"args": [["1903"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1903", "method": "animate"}, {"args": [["1904"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1904", "method": "animate"}, {"args": [["1905"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1905", "method": "animate"}, {"args": [["1906"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1906", "method": "animate"}, {"args": [["1907"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1907", "method": "animate"}, {"args": [["1908"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1908", "method": "animate"}, {"args": [["1909"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1909", "method": "animate"}, {"args": [["1910"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1910", "method": "animate"}, {"args": [["1911"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1911", "method": "animate"}, {"args": [["1912"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1912", "method": "animate"}, {"args": [["1913"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1913", "method": "animate"}, {"args": [["1914"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1914", "method": "animate"}, {"args": [["1915"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1915", "method": "animate"}, {"args": [["1916"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1916", "method": "animate"}, {"args": [["191 ...

# %% [markdown]
# # Creating some interactive graphs and maps for CO2 emissions from oil production

# %%
# Showing the top 5 countries emitting the highest amount of CO2 from oil production

top_oil = data.groupby('country')['oil_co2'].sum().reset_index().sort_values(by=['oil_co2'], ascending=False).head(5)['country'].tolist()

fig = px.line(
    data[data['country'].isin(top_oil)],
    x='year',
    y='oil_co2',
    color='country',
    title = 'Top 5 countries with highest CO2 emissions from Oil Production measured in Million Tonnes Per Year '
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7cbdb913-2cf1-48a0-9dbd-426f57226c18" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7cbdb913-2cf1-48a0-9dbd-426f57226c18")) {
#                     Plotly.newPlot(
#                         '7cbdb913-2cf1-48a0-9dbd-426f57226c18',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Austria<br>year=%{x}<br>oil_co2=%{y}", "legendgroup": "country=Austria", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "country=Austria", "showlegend": true, "type": "scatter", "x": [1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950], "xaxis": "x", "y": [0.15200803570633145, 0.14448681057292265, 0.1369666990351807, 0.1294465874974387, 0.12192647595969673, 0.11440525082628797, 0.10688513928854598, 0.099365027750804, 0.09184380261739525, 0.08432369107965328, 0.07680357954191129, 0.06928346800416929, 0.061762242870760535, 0.054242131333018556, 0.04672201979527657, 0.039200794661867815, 0.03168068312412582, 0.02416057158638384, 0.016640460048641857, 0.009119234915233098, 0.0015991233774911135, 0.0016525759694963873, 0.0016815294568325774, 0.0016815294568325774, 0.0018730679115181426, 0.0018118201498454327, 0.0019020213988543326, 0.0019510196081925005, 0.0021381036802109593, 0.0022160553768853174, 0.002399798661903447, 0.002390889896569234, 0.0022038058245507754, 0.0024476832755748377, 0.002223850546552753, 0.0023218469652290887, 0.002358595622232715, 0.0023095974128945467, 0.001522285276483532, 0.0018196153195128685, 0.0027383317446035152, 0.0035534837726839434, 0.004300706465091002, 0.005096927366836229, 0.005472209106539924, 0.002847464119947616, 0.004211618811748879, 0.004484449750109132, 0.0047093960747979936, 0.0054432556192037344, 0.0034966903936783397], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Russia<br>year=%{x}<br>oil_co2=%{y}", "legendgroup": "country=Russia", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "country=Russia", "showlegend": true, "type": "scatter", "x": [1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950], "xaxis": "x", "y": [0.020846510882056853, 0.02321401526962378, 0.022011331949505115, 0.020034699640976754, 0.020857646838724618, 0.01570503968854956, 0.01768835357107858, 0.018613751570169885, 0.018636023483505418, 0.019847615568958296, 0.02049238746002191, 0.019461197872586836, 0.01977857263761815, 0.01923179716523087, 0.01993893041363397, 0.021620459870466548, 0.023024704006271768, 0.020594838261365354, 0.00946333597626705, 0.011030165079421641, 0.009864230416306602, 0.009653760835285838, 0.011531283129471086, 0.012772942297926929, 0.013187199885967803, 0.013917718643373215, 0.016389901023617134, 0.019467879446587493, 0.019075893771882152, 0.023043635132606967, 0.041221970797067235, 0.04955723436288964, 0.04702825860364012, 0.0475605573323593, 0.053746581261302995, 0.056580682233249295, 0.06146714001906475, 0.06420992614633537, 0.06801396894404403, 0.06845829361508787, 0.07042713075394881, 0.07262759579149926, 0.0686086290301027, 0.06140477866172527, 0.08322011777387772, 0.044446943848052096, 0.050752122513340873, 0.06135243966538677, 0.06802955928337891, 0.07910204099813806, 0.08787606125667044], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=United States<br>year=%{x}<br>oil_co2=%{y}", "legendgroup": "country=United States", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "country=United States", "showlegend": true, "type": "scatter", "x": [1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 19 ...

# %% [markdown]
# Here, also we have not considered the emissions for Austria, Ireland and South Korea because these nations were not in the top emitting countries and if we observe the individual graph for this nations then we could see that the emissions were very high for the first 30 years and after that the emissions had suddenly dropped to zero.
#
# This could be because of the fact that there were a lot of missing values for these nations and while filling these missing values using the interpolate, median and mean method this discrepancy could have been created or arised.

# %%
# Showing the bottom 5 countries emitting the lowest amount of CO2 from oil production

bottom_oil = data.groupby('country')['oil_co2'].sum().reset_index().sort_values(by=['oil_co2'], ascending=True).head(5)['country'].tolist()

plt.figure(figsize=(15, 15))
g = sns.barplot(
    data = data[data['country'].isin(bottom_oil)],
    x ='country',
    y ='oil_co2',
    order = bottom_oil,
    ci=None
)

# g.set(ylim=(0,0.004))
plt.title('Bottom 5 countries with lowest CO2 emissions from Oil Production in Million Tonnes Per Year')
plt.show()

# %%
# Creating a time series chloropleth map for CO2 emissions from gas production
fig = px.choropleth(
    data.groupby(['country', 'year'])['oil_co2'].sum().reset_index().sort_values(by=['year'], ascending=True),
    locations='country',
    locationmode='country names',
    color='oil_co2',
    color_continuous_scale='Spectral_r', # (_r) is used for inverting the color ramp
    height=750,
    animation_frame='year',
    animation_group='country'
)

fig.update_layout(
    title='CO2 Emissions from Oil Production in Million Tonnes Per Year'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b79a6669-f008-4b11-ad50-ef8fb44f28dd" class="plotly-graph-div" style="height:750px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b79a6669-f008-4b11-ad50-ef8fb44f28dd")) {
#                     Plotly.newPlot(
#                         'b79a6669-f008-4b11-ad50-ef8fb44f28dd',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "year=1900<br>country=%{location}<br>oil_co2=%{z}", "ids": ["Argentina", "Japan", "Kazakhstan", "Kyrgyzstan", "Latvia", "Lithuania", "Malaysia", "Mexico", "Montenegro", "Netherlands", "Armenia", "New Zealand", "North Macedonia", "Norway", "Oceania", "Peru", "Italy", "Indonesia", "Hungary", "Greece", "Azerbaijan", "Belarus", "Belgium", "Bosnia and Herzegovina", "Australia", "Bulgaria", "Canada", "Poland", "Chile", "Czechia", "Denmark", "Estonia", "Finland", "France", "Georgia", "Germany", "Croatia", "Portugal", "Moldova", "Austria", "Taiwan", "Turkey", "Switzerland", "Turkmenistan", "Sweden", "Ukraine", "Spain", "South Africa", "Slovenia", "United States", "Slovakia", "United Kingdom", "Tajikistan", "Uzbekistan", "Serbia", "Romania", "Vietnam", "Russia"], "locationmode": "country names", "locations": ["Argentina", "Japan", "Kazakhstan", "Kyrgyzstan", "Latvia", "Lithuania", "Malaysia", "Mexico", "Montenegro", "Netherlands", "Armenia", "New Zealand", "North Macedonia", "Norway", "Oceania", "Peru", "Italy", "Indonesia", "Hungary", "Greece", "Azerbaijan", "Belarus", "Belgium", "Bosnia and Herzegovina", "Australia", "Bulgaria", "Canada", "Poland", "Chile", "Czechia", "Denmark", "Estonia", "Finland", "France", "Georgia", "Germany", "Croatia", "Portugal", "Moldova", "Austria", "Taiwan", "Turkey", "Switzerland", "Turkmenistan", "Sweden", "Ukraine", "Spain", "South Africa", "Slovenia", "United States", "Slovakia", "United Kingdom", "Tajikistan", "Uzbekistan", "Serbia", "Romania", "Vietnam", "Russia"], "name": "", "type": "choropleth", "z": [0.0018140473411789857, 0.0024198433839054245, 0.0023173925825619827, 0.001493331789147342, 0.001592441803490454, 0.0018997942075207794, 0.0024922271022458998, 0.0029588236866252703, 0.005938805690919295, 0.0019020213988543326, 0.0016926654135003428, 0.004405384457767997, 0.00480071091947367, 0.0014610375148108223, 0.0014610375148108223, 0.0014565831321437161, 0.0016280768648273035, 0.00207351513153792, 0.0013340876087982966, 0.01293330007394275, 0.002505590250247218, 0.0035646197293517086, 0.020288599453001804, 0.001682643052499354, 0.0014610375148108223, 0.0036793200830296927, 0.0017461180055056169, 0.002513385419914654, 0.0023663907919001504, 0.007964436208785824, 0.0038396778590455145, 0.0014599239191440457, 0.0013919945834706766, 0.0021458988498783953, 0.001799570597510891, 0.004700487309463781, 0.005396484601199119, 0.0013752906484690286, 0.0016525759694963873, 0.15200803570633145, 0.019933362435300087, 0.017307503853041004, 0.0015668291031545936, 0.002178193124214915, 0.0015991233774911135, 0.005015634883161542, 0.0014732870671453641, 0.0021748523372145854, 0.011709458436155333, 0.02877753922083938, 0.0021091501928747693, 0.004729440796799971, 0.0014576967278104927, 0.0027951251236091185, 0.008447736728166842, 0.0021748523372145854, 0.052866840684549526, 0.020846510882056853]}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "oil_co2"}}, "colorscale": [[0.0, "rgb(94,79,162)"], [0.1, "rgb(50,136,189)"], [0.2, "rgb(102,194,165)"], [0.3, "rgb(171,221,164)"], [0.4, "rgb(230,245,152)"], [0.5, "rgb(255,255,191)"], [0.6, "rgb(254,224,139)"], [0.7, "rgb(253,174,97)"], [0.8, "rgb(244,109,67)"], [0.9, "rgb(213,62,79)"], [1.0, "rgb(158,1,66)"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}}, "height": 750, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "sliders": [{"active": 0, "currentvalue": {"prefix": "year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1900"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1900", "method": "animate"}, {"args": [["1901"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1901", "method": "animate"}, {"args": [["1902"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1902", "method": "animate"}, {"args": [["1903"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1903", "method": "animate"}, {"args": [["1904"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1904", "method": "animate"}, {"args": [["1905"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1905", "method": "animate"}, {"args": [["1906"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1906", "method": "animate"}, {"args": [["1907"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1907", "method": "animate"}, {"args": [["1908"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1908", "method": "animate"}, {"args": [["1909"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1909", "method": "animate"}, {"args": [["1910"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1910", "method": "animate"}, {"args": [["1911"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1911", "method": "animate"}, {"args": [["1912"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1912", "method": "animate"}, {"args": [["1913"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1913", "method": "animate"}, {"args": [["1914"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1914", "method": "animate"}, {"args": [["1915"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1915", "method": "animate"}, {"args": [["1916"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1916", "method": "animate"}, {"args": [["191 ...
