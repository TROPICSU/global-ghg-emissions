# %% [markdown]
# # Loading the gdrive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# # Importing the Libraries

# %%
import numpy as np                    # Mathematical Calculations
import pandas as pd                   # Manipulation of raw data
import matplotlib.pyplot as plt       # Plotting the graphs
import seaborn as sns
import plotly.express as px           # For creating interactive publication quality graphs
# %matplotlib inline

# %% [markdown]
# # Importing the Dataset

# %%
data = pd.read_excel('/gdrive/My Drive/TROP-ICSU-Internship-Sahil-Ashutosh/Assignment-1-Emissions/Analysis/Data/1951-1990/Sectors/Sources_(1951-1990).xlsx')

# %%
data.head()
# Out:
#        country  year  cement_co2  ...  gas_co2  oil_co2  other_industry_co2
# 0  Afghanistan  1951       0.414  ...    2.287    0.066               1.379
# 1  Afghanistan  1952       0.414  ...    2.287    0.060               1.379
# 2  Afghanistan  1953       0.414  ...    2.287    0.068               1.379
# 3  Afghanistan  1954       0.414  ...    2.287    0.064               1.379
# 4  Afghanistan  1955       0.414  ...    2.287    0.092               1.379
#
# [5 rows x 8 columns]

# %%
data.tail()
# Out:
#        country  year  cement_co2  ...  gas_co2  oil_co2  other_industry_co2
# 6866  Zimbabwe  1986       0.325  ...    1.249    1.894              27.588
# 6867  Zimbabwe  1987       0.346  ...    1.249    1.821              27.588
# 6868  Zimbabwe  1988       0.326  ...    1.249    2.301              27.588
# 6869  Zimbabwe  1989       0.300  ...    1.249    2.202              27.588
# 6870  Zimbabwe  1990       0.287  ...    1.249    1.868              27.588
#
# [5 rows x 8 columns]

# %%
data = data.round(4)

# %%
data.drop('other_industry_co2', axis = 1, inplace = True)

# %% [markdown]
# # Normalizing the data into the scale of 0 and +1 by using min-max scaler function

# %%
from sklearn.preprocessing import MinMaxScaler
# Storing the MinMaxScaler in the variable scalerr
scaler = MinMaxScaler()

# %%
# Performing the scaling on the cement_co2 attribute
scaler.fit(data[['cement_co2']])
data[['cement_co2']]=scaler.transform(data[['cement_co2']])
data.head()
# Out:
#        country  year  cement_co2  coal_co2  flaring_co2  gas_co2  oil_co2
# 0  Afghanistan  1951    0.004857     0.026        0.578    2.287    0.066
# 1  Afghanistan  1952    0.004857     0.032        0.578    2.287    0.060
# 2  Afghanistan  1953    0.004857     0.038        0.578    2.287    0.068
# 3  Afghanistan  1954    0.004857     0.043        0.578    2.287    0.064
# 4  Afghanistan  1955    0.004857     0.062        0.578    2.287    0.092

# %%
# Performing the scaling on the coal_co2 attribute
scaler.fit(data[['coal_co2']])
data[['coal_co2']]=scaler.transform(data[['coal_co2']])
data.head()
# Out:
#        country  year  cement_co2  coal_co2  flaring_co2  gas_co2  oil_co2
# 0  Afghanistan  1951    0.004857  0.000071        0.578    2.287    0.066
# 1  Afghanistan  1952    0.004857  0.000074        0.578    2.287    0.060
# 2  Afghanistan  1953    0.004857  0.000077        0.578    2.287    0.068
# 3  Afghanistan  1954    0.004857  0.000079        0.578    2.287    0.064
# 4  Afghanistan  1955    0.004857  0.000089        0.578    2.287    0.092

# %%
# Performing the scaling on the flaring_co2 attribute
scaler.fit(data[['flaring_co2']])
data[['flaring_co2']]=scaler.transform(data[['flaring_co2']])
data.head()
# Out:
#        country  year  cement_co2  coal_co2  flaring_co2  gas_co2  oil_co2
# 0  Afghanistan  1951    0.004857  0.000071     0.007688    2.287    0.066
# 1  Afghanistan  1952    0.004857  0.000074     0.007688    2.287    0.060
# 2  Afghanistan  1953    0.004857  0.000077     0.007688    2.287    0.068
# 3  Afghanistan  1954    0.004857  0.000079     0.007688    2.287    0.064
# 4  Afghanistan  1955    0.004857  0.000089     0.007688    2.287    0.092

# %%
# Performing the scaling on the gas_co2 attribute
scaler.fit(data[['gas_co2']])
data[['gas_co2']]=scaler.transform(data[['gas_co2']])
data.head()
# Out:
#        country  year  cement_co2  coal_co2  flaring_co2   gas_co2  oil_co2
# 0  Afghanistan  1951    0.004857  0.000071     0.007688  0.002181    0.066
# 1  Afghanistan  1952    0.004857  0.000074     0.007688  0.002181    0.060
# 2  Afghanistan  1953    0.004857  0.000077     0.007688  0.002181    0.068
# 3  Afghanistan  1954    0.004857  0.000079     0.007688  0.002181    0.064
# 4  Afghanistan  1955    0.004857  0.000089     0.007688  0.002181    0.092

# %%
# Performing the scaling on the oil_co2 attribute
scaler.fit(data[['oil_co2']])
data[['oil_co2']]=scaler.transform(data[['oil_co2']])
data.head()
# Out:
#        country  year  cement_co2  coal_co2  flaring_co2   gas_co2   oil_co2
# 0  Afghanistan  1951    0.004857  0.000071     0.007688  0.002181  0.000318
# 1  Afghanistan  1952    0.004857  0.000074     0.007688  0.002181  0.000315
# 2  Afghanistan  1953    0.004857  0.000077     0.007688  0.002181  0.000318
# 3  Afghanistan  1954    0.004857  0.000079     0.007688  0.002181  0.000317
# 4  Afghanistan  1955    0.004857  0.000089     0.007688  0.002181  0.000328

# %% [markdown]
# # Creating some interactive graphs and maps for CO2 emissions from Cement Production

# %%
# Showing the top 5 countries emitting the highest amount of CO2 from Cement Production

top_cement = data.groupby('country')['cement_co2'].sum().reset_index().sort_values(by=['cement_co2'], ascending=False).head(5)['country'].tolist()

fig = px.line(
    data[data['country'].isin(top_cement)],
    x='year',
    y='cement_co2',
    color='country',
    title = 'Top 5 countries with highest CO2 emissions from Cement Production measured in Million Tonnes Per Year '
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4e37da28-baa9-44a8-a7a1-a6eb6c5a231b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4e37da28-baa9-44a8-a7a1-a6eb6c5a231b")) {
#                     Plotly.newPlot(
#                         '4e37da28-baa9-44a8-a7a1-a6eb6c5a231b',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "country=China<br>year=%{x}<br>cement_co2=%{y}", "legendgroup": "country=China", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "country=China", "showlegend": true, "type": "scatter", "x": [1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990], "xaxis": "x", "y": [0.006334125098970705, 0.014039068316375369, 0.019061462284775645, 0.022606681556587606, 0.022098533460961228, 0.031398825350681274, 0.03370321787735905, 0.04570969381122889, 0.06032781460866688, 0.06636650476831991, 0.039316481724394656, 0.039316481724394656, 0.0491485565048865, 0.051606575200009455, 0.05406459389513242, 0.05406459389513242, 0.03928102953167654, 0.0442679713073587, 0.04911310431216837, 0.04904219992673213, 0.11265525106061143, 0.11271433804847497, 0.12232188227508536, 0.12212098651634937, 0.14644119072097944, 0.24005861429196063, 0.2705002304392527, 0.31662353316552627, 0.3580198768627173, 0.38626345706148596, 0.4056085368880065, 0.45349263185261346, 0.5209463371976223, 0.581723212914052, 0.6835773625932097, 0.7731886883870434, 0.8586166554401389, 1.0, 0.9853346096122712, 0.9986882688694296], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Germany<br>year=%{x}<br>cement_co2=%{y}", "legendgroup": "country=Germany", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "country=Germany", "showlegend": true, "type": "scatter", "x": [1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990], "xaxis": "x", "y": [0.08221363491331939, 0.08818142068753619, 0.10574207348057811, 0.11201711159168527, 0.12515805769253496, 0.1312085652497607, 0.13211850486285912, 0.1357228111225346, 0.15981848477328323, 0.17480294489547513, 0.18931470911475876, 0.19872135758263315, 0.20246747261318113, 0.2300847307405963, 0.23489441155268787, 0.2405194927972962, 0.2269885725765472, 0.23939684002788905, 0.24816534902683732, 0.27045296084896187, 0.2864064475721157, 0.29827111473511303, 0.2873518393779322, 0.25940369411848124, 0.246286382812777, 0.2583873979272285, 0.2490516538447903, 0.25922643315489063, 0.26468607083348106, 0.24783446189480154, 0.2300256437527328, 0.21780645466255424, 0.21788917644556316, 0.20657992696848304, 0.1888183784167051, 0.192848110988998, 0.18652580328760002, 0.18959832665650372, 0.19743326124720817, 0.18073527847697382], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Japan<br>year=%{x}<br>cement_co2=%{y}", "legendgroup": "country=Japan", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "country=Japan", "showlegend": true, "type": "scatter", "x": [1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990], "xaxis": "x", "y": [0.03822928114770566, 0.041538152468063486, 0.05115751409224661, 0.06232495479845429, 0.06167499793195543, 0.07602131858522115, 0.08860684700015363, 0.08749601162831921, 0.10080240129518676, 0.13159853936966, 0.143841363254984, 0.16810248047175053, 0.17488566667848407, 0.1925881282423985, 0.19091005778707415, 0.22346698809988066, 0.2509542548539961, 0.2784415216081115, 0.30012644615402795, 0.33400692499497764, 0.34585977476040225, 0.3843844908474256, 0.45129459590409005, 0.42082934496165253, 0.3757223384266317, 0.3926093995580293, 0.4163623686791695, 0.4814289597144917, 0.4961298022949386, 0.495148958296404, 0.47576842627716526, 0.4508455347963272, 0.45025466491769184, 0.43729097978043274, 0.40239420474 ...
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "widt

# %% [markdown]
# While doing the report we have not considered the emissions for Germany because the nation had got divided into East Germany and West Germany after the end of Second World War where the East Germany was controlled by the United States and West Germany was controlled by the Soviet Union.

# %%
# Showing the bottom 5 countries emitting the lowest amount of CO2 from Cement Production

bottom_cement = data.groupby('country')['cement_co2'].sum().reset_index().sort_values(by=['cement_co2'], ascending=True).head(5)['country'].tolist()

plt.figure(figsize=(10,10))
g = sns.barplot(
    data = data[data['country'].isin(bottom_cement)],
    x ='country',
    y ='cement_co2',
    order = bottom_cement,
    ci=None
)
plt.title('Bottom 5 countries with lowest CO2 emissions from Cement Production measured in Million Tonnes Per Year')
plt.show()

# %%
# Creating a time series chloropleth map for CO2 emissions from cement productions
fig = px.choropleth(
    data.groupby(['country', 'year'])['cement_co2'].sum().reset_index().sort_values(by=['year'], ascending=True),
    locations='country',
    locationmode='country names',
    color='cement_co2',
    color_continuous_scale='Spectral_r', # (_r) is used for inverting the color ramp
    height=750,
    animation_frame='year',
    animation_group='country'
)

fig.update_layout(
    title='CO2 Emissions from Cement Production in Million Tonnes Per Year'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4fc9f465-12f4-4a51-b46c-69c2bb62e53d" class="plotly-graph-div" style="height:750px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4fc9f465-12f4-4a51-b46c-69c2bb62e53d")) {
#                     Plotly.newPlot(
#                         '4fc9f465-12f4-4a51-b46c-69c2bb62e53d',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "year=1951<br>country=%{location}<br>cement_co2=%{z}", "ids": ["Afghanistan", "Cameroon", "Mauritius", "Saint Pierre and Miquelon", "Canada", "France", "Mexico", "Australia", "Finland", "Moldova", "Saint Lucia", "Russia", "Turkmenistan", "Chile", "Fiji", "Mongolia", "Romania", "Montenegro", "China", "Thailand", "Saint Vincent and the Grenadines", "Malta", "Venezuela", "Samoa", "Tajikistan", "Sierra Leone", "Greece", "Bulgaria", "Germany", "Madagascar", "Serbia", "Malawi", "Saudi Arabia", "Faeroe Islands", "Uruguay", "Uganda", "Georgia", "Trinidad and Tobago", "United States", "Tanzania", "Angola", "Sao Tome and Principe", "Gambia", "Yemen", "Burundi", "Austria", "Qatar", "Morocco", "New Zealand", "Panama", "Zambia", "Cyprus", "Dominican Republic", "Nicaragua", "Pakistan", "Tunisia", "Czechia", "Dominica", "Nigeria", "Oceania", "Djibouti", "Norway", "Democratic Republic of Congo", "North Korea", "Armenia", "Denmark", "North Macedonia", "Ecuador", "Cuba", "Papua New Guinea", "Argentina", "Colombia", "Mozambique", "Portugal", "Eswatini", "Poland", "Myanmar", "Philippines", "Turkey", "Peru", "Ethiopia", "Costa Rica", "Nepal", "Aruba", "Equatorial Guinea", "Netherlands", "Paraguay", "Croatia", "Egypt", "New Caledonia", "Togo", "Estonia", "Luxembourg", "Malaysia", "Kenya", "Hungary", "Japan", "Kazakhstan", "Spain", "Albania", "South Korea", "Bermuda", "Hong Kong", "Greenland", "South Africa", "Azerbaijan", "Honduras", "Kuwait", "Zimbabwe", "Haiti", "Bolivia", "Taiwan", "United Kingdom", "Belize", "Sri Lanka", "Belgium", "Switzerland", "Bahrain", "Iran", "Iraq", "Bahamas", "Sweden", "Indonesia", "Barbados", "Kyrgyzstan", "Ireland", "Suriname", "India", "Vietnam", "Israel", "Belarus", "Sudan", "Iceland", "Italy", "Syria", "Somalia", "Uzbekistan", "Ukraine", "Guatemala", "Guyana", "Algeria", "Slovakia", "Libya", "Sint Maarten (Dutch part)", "Liberia", "Bosnia and Herzegovina", "Lebanon", "Singapore", "Grenada", "Lithuania", "Slovenia", "Brazil", "Bonaire Sint Eustatius and Saba", "Guinea-Bissau", "Brunei", "Latvia"], "locationmode": "country names", "locations": ["Afghanistan", "Cameroon", "Mauritius", "Saint Pierre and Miquelon", "Canada", "France", "Mexico", "Australia", "Finland", "Moldova", "Saint Lucia", "Russia", "Turkmenistan", "Chile", "Fiji", "Mongolia", "Romania", "Montenegro", "China", "Thailand", "Saint Vincent and the Grenadines", "Malta", "Venezuela", "Samoa", "Tajikistan", "Sierra Leone", "Greece", "Bulgaria", "Germany", "Madagascar", "Serbia", "Malawi", "Saudi Arabia", "Faeroe Islands", "Uruguay", "Uganda", "Georgia", "Trinidad and Tobago", "United States", "Tanzania", "Angola", "Sao Tome and Principe", "Gambia", "Yemen", "Burundi", "Austria", "Qatar", "Morocco", "New Zealand", "Panama", "Zambia", "Cyprus", "Dominican Republic", "Nicaragua", "Pakistan", "Tunisia", "Czechia", "Dominica", "Nigeria", "Oceania", "Djibouti", "Norway", "Democratic Republic of Congo", "North Korea", "Armenia", "Denmark", "North Macedonia", "Ecuador", "Cuba", "Papua New Guinea", "Argentina", "Colombia", "Mozambique", "Portugal", "Eswatini", "Poland", "Myanmar", "Philippines", "Turkey", "Peru", "Ethiopia", "Costa Rica", "Nepal", "Aruba", "Equatorial Guinea", "Netherlands", "Paraguay", "Croatia", "Egypt", "New Caledonia", "Togo", "Estonia", "Luxembourg", "Malaysia", "Kenya", "Hungary", "Japan", "Kazakhstan", "Spain", "Albania", "South Korea", "Bermuda", "Hong Kong", "Greenland", "South Africa", "Azerbaijan", "Honduras", "Kuwait", "Zimbabwe", "Haiti", "Bolivia", "Taiwan", "United Kingdom", "Belize", "Sri Lanka", "Belgium", "Switzerland", "Bahrain", "Iran", "Iraq", "Bahamas", "Sweden", "Indonesia", "Barbados", "Kyrgyzstan", "Ireland", "Suriname", "India", "Vietnam", "Israel", "Belarus", "Sudan", "Iceland", "Italy", "Syria", "Somalia", "Uzbekistan", "Ukraine", "Guatemala", "Guyana", "Algeria", "Slovakia", "Libya", "Sint Maarten (Dutch  ...

# %% [markdown]
# # Creating some interactive graphs and maps for CO2 emissions from coal production

# %%
# Showing the top 5 countries emitting the highest amount of CO2 from Coal Production

top_coal = data.groupby('country')['coal_co2'].sum().reset_index().sort_values(by=['coal_co2'], ascending=False).head(5)['country'].tolist()

fig = px.line(
    data[data['country'].isin(top_coal)],
    x='year',
    y='coal_co2',
    color='country',
    title = 'Top 5 countries with highest CO2 emissions from Coal Production measured in Million Tonnes Per Year '
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="014fdfcc-ce66-49f5-b900-220dba3327f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("014fdfcc-ce66-49f5-b900-220dba3327f7")) {
#                     Plotly.newPlot(
#                         '014fdfcc-ce66-49f5-b900-220dba3327f7',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "country=China<br>year=%{x}<br>coal_co2=%{y}", "legendgroup": "country=China", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "country=China", "showlegend": true, "type": "scatter", "x": [1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990], "xaxis": "x", "y": [0.05071180768090619, 0.06351584734504992, 0.06594047545576229, 0.0787667733374882, 0.09273076965881187, 0.1037723631853128, 0.12339348785257774, 0.25712743537781807, 0.3518579035389554, 0.3786375745017953, 0.26436135609202355, 0.2084375844168195, 0.2055050642503685, 0.20320133873061383, 0.21909522369002798, 0.23769702316574579, 0.19410835097971565, 0.20883974993904283, 0.25358736704509005, 0.33689835784941097, 0.3725914332167474, 0.38994171382204956, 0.39652761688346505, 0.39266278092146994, 0.4586973479333751, 0.4605953668508365, 0.5052225872345075, 0.5653389977124622, 0.5805656420129927, 0.5679781141016936, 0.5691623524507815, 0.6318146821273595, 0.668736512278948, 0.735690748371862, 0.8016120008215305, 0.8384797030349079, 0.8955811367676413, 0.9575141213214501, 0.9714462479221447, 0.9999999999999999], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Germany<br>year=%{x}<br>coal_co2=%{y}", "legendgroup": "country=Germany", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "country=Germany", "showlegend": true, "type": "scatter", "x": [1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990], "xaxis": "x", "y": [0.28272387972873303, 0.29870325647840595, 0.3021563154151309, 0.31646531410897827, 0.34520927277344465, 0.3618184559069768, 0.36436904529446096, 0.3484640312262558, 0.33932045661721627, 0.35781501195367454, 0.3600565156379154, 0.3703600469041349, 0.3853711911889834, 0.3822995571626438, 0.3627234547991246, 0.3441004088429874, 0.3308279348724553, 0.33374123203281264, 0.3471760898179783, 0.30521479685835373, 0.297575169541855, 0.2800948807111298, 0.28431837749734673, 0.28630037059932273, 0.2610752337871649, 0.2813064359636138, 0.26141365986813014, 0.26500178571609234, 0.27786703547858704, 0.27888029024715727, 0.2822053644327847, 0.27869665995210435, 0.2801763255527373, 0.28958194008694865, 0.293145784243003, 0.2903058380269506, 0.2834573891717818, 0.2797326788068381, 0.2766559860946844, 0.28785237540709774], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Russia<br>year=%{x}<br>coal_co2=%{y}", "legendgroup": "country=Russia", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "country=Russia", "showlegend": true, "type": "scatter", "x": [1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990], "xaxis": "x", "y": [0.17933698840245688, 0.1897416933849589, 0.1983768700696783, 0.21551367413362416, 0.24206722184057244, 0.25958039212908957, 0.2773328382566149, 0.28597762644438124, 0.2920176973064521, 0.2924188510915126, 0.2871269598613515, 0.284862692090947, 0.2952729616278446, 0.30392938479298337, 0.31415703577199083, 0.3246720201052409, 0.326821961576246, 0.3230173239754391, 0.32732580668333333, 0.3494828505492215, 0.3561527277951515, 0.36681896683424403, 0.3703312123949943, 0.37081886970747635, 0.3817896416325795, 0.39192471866118844, 0.3980998564344966, 0.395449610936474, 0.39589426941953604, 0.41737749633498206, 0.37769767067753, 0.38284791870489543, 0.38001505464898283, 0.3776865415687389, 0.4308943048303367, 0.4436578750079674 ...
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5

# %% [markdown]
# While doing the report we have not considered the emissions for Germany because the nation had got divided into East Germany and West Germany after the end of Second World War where the East Germany was controlled by the United States and West Germany was controlled by the Soviet Union.

# %%
# Showing the bottom 5 countries emitting the lowest amount of CO2 from Coal Production

bottom_coal = data.groupby('country')['coal_co2'].sum().reset_index().sort_values(by=['coal_co2'], ascending=True).head(5)['country'].tolist()

plt.figure(figsize=(15, 15))
g = sns.barplot(
    data = data[data['country'].isin(bottom_coal)],
    x ='country',
    y ='cement_co2',
    order = bottom_coal,
    ci=None
)

#g.set(ylim=(0,0.004))
plt.title('Bottom 5 countries with lowest CO2 emissions from Cement Production measured in Million Tonnes Per Year')
plt.show()

# %%
# Creating a time series chloropleth map for CO2 emissions from coal productions
fig = px.choropleth(
    data.groupby(['country', 'year'])['coal_co2'].sum().reset_index().sort_values(by=['year'], ascending=True),
    locations='country',
    locationmode='country names',
    color='coal_co2',
    color_continuous_scale='Spectral_r', # (_r) is used for inverting the color ramp
    height=750,
    animation_frame='year',
    animation_group='country'
)

fig.update_layout(
    title='CO2 Emissions from Coal Production in Million Tonnes Per Year'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2caa118d-346d-4f63-a256-a7f8dc2634b8" class="plotly-graph-div" style="height:750px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2caa118d-346d-4f63-a256-a7f8dc2634b8")) {
#                     Plotly.newPlot(
#                         '2caa118d-346d-4f63-a256-a7f8dc2634b8',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "year=1951<br>country=%{location}<br>coal_co2=%{z}", "ids": ["Afghanistan", "Cameroon", "Mauritius", "Saint Pierre and Miquelon", "Canada", "France", "Mexico", "Australia", "Finland", "Moldova", "Saint Lucia", "Russia", "Turkmenistan", "Chile", "Fiji", "Mongolia", "Romania", "Montenegro", "China", "Thailand", "Saint Vincent and the Grenadines", "Malta", "Venezuela", "Samoa", "Tajikistan", "Sierra Leone", "Greece", "Bulgaria", "Germany", "Madagascar", "Serbia", "Malawi", "Saudi Arabia", "Faeroe Islands", "Uruguay", "Uganda", "Georgia", "Trinidad and Tobago", "United States", "Tanzania", "Angola", "Sao Tome and Principe", "Gambia", "Yemen", "Burundi", "Austria", "Qatar", "Morocco", "New Zealand", "Panama", "Zambia", "Cyprus", "Dominican Republic", "Nicaragua", "Pakistan", "Tunisia", "Czechia", "Dominica", "Nigeria", "Oceania", "Djibouti", "Norway", "Democratic Republic of Congo", "North Korea", "Armenia", "Denmark", "North Macedonia", "Ecuador", "Cuba", "Papua New Guinea", "Argentina", "Colombia", "Mozambique", "Portugal", "Eswatini", "Poland", "Myanmar", "Philippines", "Turkey", "Peru", "Ethiopia", "Costa Rica", "Nepal", "Aruba", "Equatorial Guinea", "Netherlands", "Paraguay", "Croatia", "Egypt", "New Caledonia", "Togo", "Estonia", "Luxembourg", "Malaysia", "Kenya", "Hungary", "Japan", "Kazakhstan", "Spain", "Albania", "South Korea", "Bermuda", "Hong Kong", "Greenland", "South Africa", "Azerbaijan", "Honduras", "Kuwait", "Zimbabwe", "Haiti", "Bolivia", "Taiwan", "United Kingdom", "Belize", "Sri Lanka", "Belgium", "Switzerland", "Bahrain", "Iran", "Iraq", "Bahamas", "Sweden", "Indonesia", "Barbados", "Kyrgyzstan", "Ireland", "Suriname", "India", "Vietnam", "Israel", "Belarus", "Sudan", "Iceland", "Italy", "Syria", "Somalia", "Uzbekistan", "Ukraine", "Guatemala", "Guyana", "Algeria", "Slovakia", "Libya", "Sint Maarten (Dutch part)", "Liberia", "Bosnia and Herzegovina", "Lebanon", "Singapore", "Grenada", "Lithuania", "Slovenia", "Brazil", "Bonaire Sint Eustatius and Saba", "Guinea-Bissau", "Brunei", "Latvia"], "locationmode": "country names", "locations": ["Afghanistan", "Cameroon", "Mauritius", "Saint Pierre and Miquelon", "Canada", "France", "Mexico", "Australia", "Finland", "Moldova", "Saint Lucia", "Russia", "Turkmenistan", "Chile", "Fiji", "Mongolia", "Romania", "Montenegro", "China", "Thailand", "Saint Vincent and the Grenadines", "Malta", "Venezuela", "Samoa", "Tajikistan", "Sierra Leone", "Greece", "Bulgaria", "Germany", "Madagascar", "Serbia", "Malawi", "Saudi Arabia", "Faeroe Islands", "Uruguay", "Uganda", "Georgia", "Trinidad and Tobago", "United States", "Tanzania", "Angola", "Sao Tome and Principe", "Gambia", "Yemen", "Burundi", "Austria", "Qatar", "Morocco", "New Zealand", "Panama", "Zambia", "Cyprus", "Dominican Republic", "Nicaragua", "Pakistan", "Tunisia", "Czechia", "Dominica", "Nigeria", "Oceania", "Djibouti", "Norway", "Democratic Republic of Congo", "North Korea", "Armenia", "Denmark", "North Macedonia", "Ecuador", "Cuba", "Papua New Guinea", "Argentina", "Colombia", "Mozambique", "Portugal", "Eswatini", "Poland", "Myanmar", "Philippines", "Turkey", "Peru", "Ethiopia", "Costa Rica", "Nepal", "Aruba", "Equatorial Guinea", "Netherlands", "Paraguay", "Croatia", "Egypt", "New Caledonia", "Togo", "Estonia", "Luxembourg", "Malaysia", "Kenya", "Hungary", "Japan", "Kazakhstan", "Spain", "Albania", "South Korea", "Bermuda", "Hong Kong", "Greenland", "South Africa", "Azerbaijan", "Honduras", "Kuwait", "Zimbabwe", "Haiti", "Bolivia", "Taiwan", "United Kingdom", "Belize", "Sri Lanka", "Belgium", "Switzerland", "Bahrain", "Iran", "Iraq", "Bahamas", "Sweden", "Indonesia", "Barbados", "Kyrgyzstan", "Ireland", "Suriname", "India", "Vietnam", "Israel", "Belarus", "Sudan", "Iceland", "Italy", "Syria", "Somalia", "Uzbekistan", "Ukraine", "Guatemala", "Guyana", "Algeria", "Slovakia", "Libya", "Sint Maarten (Dutch pa ...

# %% [markdown]
# # Creating some interactive graphs and maps for CO2 emissions from gas flaring

# %%
# Showing the top 5 countries emitting the highest amount of CO2 from gas flaring

top_flaring = data.groupby('country')['flaring_co2'].sum().reset_index().sort_values(by=['flaring_co2'], ascending=False).head(5)['country'].tolist()

fig = px.line(
    data[data['country'].isin(top_flaring)],
    x='year',
    y='flaring_co2',
    color='country',
    title = 'Top 5 countries with highest CO2 emissions from gas flaring measured in Million Tonnes Per Year '
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3e338cbb-8c39-4f84-8a2e-addb7b41525b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3e338cbb-8c39-4f84-8a2e-addb7b41525b")) {
#                     Plotly.newPlot(
#                         '3e338cbb-8c39-4f84-8a2e-addb7b41525b',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Iran<br>year=%{x}<br>flaring_co2=%{y}", "legendgroup": "country=Iran", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "country=Iran", "showlegend": true, "type": "scatter", "x": [1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990], "xaxis": "x", "y": [0.1541929906231296, 0.15435259692757863, 0.1545122032320277, 0.1546718095364767, 0.15483141584092572, 0.16963490057857286, 0.11523575181219659, 0.13128948593469442, 0.14907228835539005, 0.16865066170113718, 0.19139456008512337, 0.20980248719824432, 0.23750748154552104, 0.27329919531821506, 0.3400811332047616, 0.4477887876571125, 0.4784597991620669, 0.545906763317151, 0.5701270200172908, 0.4785130012635499, 0.550734854026734, 0.6174236882356853, 0.728310168251646, 0.7205160603843852, 0.6081931236283833, 0.7199840393695551, 0.6807873911019485, 0.6638957238810933, 0.4038571523575181, 0.2422956706789918, 0.196887677063244, 0.3645674004123163, 0.3287490855888808, 0.1662299660836603, 0.13805945334840727, 0.13553235352796436, 0.1227638491720423, 0.10229434062645475, 0.038358715169249186, 0.290204163064441], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Saudi Arabia<br>year=%{x}<br>flaring_co2=%{y}", "legendgroup": "country=Saudi Arabia", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "country=Saudi Arabia", "showlegend": true, "type": "scatter", "x": [1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990], "xaxis": "x", "y": [0.24024738977189597, 0.24076611026135533, 0.24127153022544393, 0.24179025071490323, 0.24230897120436257, 0.24282769169382193, 0.24333311165791052, 0.24385183214736983, 0.24437055263682916, 0.24488927312628847, 0.24539469309037706, 0.24591341357983643, 0.24643213406929573, 0.24695085455875507, 0.24745627452284366, 0.24797499501230297, 0.24849371550176233, 0.26930903770698944, 0.3137859945467846, 0.3794506883021879, 0.5090111059386846, 0.6922657444969077, 0.9720289951453082, 1.0, 0.7462525769767906, 0.9571989093569195, 0.9568796967480215, 0.8328921992418701, 0.866276517922458, 0.9815787723615083, 0.6544922524439715, 0.5467978985169913, 0.4175300924386513, 0.10794706390902441, 0.07928443173505353, 0.061408525636762655, 0.0511671211012835, 0.0844051340027931, 0.10487464254838066, 0.006144842721287491], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=United States<br>year=%{x}<br>flaring_co2=%{y}", "legendgroup": "country=United States", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "country=United States", "showlegend": true, "type": "scatter", "x": [1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990], "xaxis": "x", "y": [0.5679324333311166, 0.6076079005120703, 0.5801689166722085, 0.5180820642415375, 0.5539003790649731, 0.6188601449757266, 0.5793442840992219, 0.4535080135665359, 0.40907095830285295, 0.403218727139722, 0.375048214404469, 0.30487464254838065, 0.2746558489060318, 0.24488927312628847, 0.22860943007248785, 0.26910952982642816, 0.3509210613819246, 0.36998071423821244, 0.376604375872847, 0.349125490456873, 0.20297931768304847, 0.17700339163396955, 0.17539402806410853, 0.11837467579969409, 0.09459333643678926, 0.09761255569595, 0.09658841524240207, 0.10804016758661966, 0.11793575846245928, 0.08898051473033185, 0.06958834873977522, 0.0663696216000532, 0.06768637361175767, 0.07699674137128416, 0.067 ...
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "t

# %% [markdown]
# Here, also we have not considered the emissions for Uruguay while preparing the report because we had found that the country was not in the list of top emitters for this period.
#
# It is being shown in the top emitters because of the fact that there were a lot of missing values for these nations and while filling these missing values using the interpolate, median and mean method this discrepancy could have been created or arised.

# %%
# Showing the bottom 5 countries emitting the lowest amount of CO2 from gas flaring

bottom_flaring = data.groupby('country')['flaring_co2'].sum().reset_index().sort_values(by=['flaring_co2'], ascending=True).head(5)['country'].tolist()

plt.figure(figsize=(15, 15))
g = sns.barplot(
    data = data[data['country'].isin(bottom_flaring)],
    x ='country',
    y ='flaring_co2',
    order = bottom_flaring,
    ci=None
)

# g.set(ylim=(0,0.004))
plt.title('Bottom 5 countries with lowest CO2 emissions from gas flaring in Million Tonnes Per Year')
plt.show()

# %%
# Creating a time series chloropleth map for CO2 emissions from gas flaring
fig = px.choropleth(
    data.groupby(['country', 'year'])['flaring_co2'].sum().reset_index().sort_values(by=['year'], ascending=True),
    locations='country',
    locationmode='country names',
    color='flaring_co2',
    color_continuous_scale='Spectral_r', # (_r) is used for inverting the color ramp
    height=750,
    animation_frame='year',
    animation_group='country'
)

fig.update_layout(
    title='CO2 Emissions from gas flaring in Million Tonnes Per Year'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5dbe008a-5f28-4f09-808a-d5d1f7a1d516" class="plotly-graph-div" style="height:750px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5dbe008a-5f28-4f09-808a-d5d1f7a1d516")) {
#                     Plotly.newPlot(
#                         '5dbe008a-5f28-4f09-808a-d5d1f7a1d516',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "year=1951<br>country=%{location}<br>flaring_co2=%{z}", "ids": ["Afghanistan", "Cameroon", "Mauritius", "Saint Pierre and Miquelon", "Canada", "France", "Mexico", "Australia", "Finland", "Moldova", "Saint Lucia", "Russia", "Turkmenistan", "Chile", "Fiji", "Mongolia", "Romania", "Montenegro", "China", "Thailand", "Saint Vincent and the Grenadines", "Malta", "Venezuela", "Samoa", "Tajikistan", "Sierra Leone", "Greece", "Bulgaria", "Germany", "Madagascar", "Serbia", "Malawi", "Saudi Arabia", "Faeroe Islands", "Uruguay", "Uganda", "Georgia", "Trinidad and Tobago", "United States", "Tanzania", "Angola", "Sao Tome and Principe", "Gambia", "Yemen", "Burundi", "Austria", "Qatar", "Morocco", "New Zealand", "Panama", "Zambia", "Cyprus", "Dominican Republic", "Nicaragua", "Pakistan", "Tunisia", "Czechia", "Dominica", "Nigeria", "Oceania", "Djibouti", "Norway", "Democratic Republic of Congo", "North Korea", "Armenia", "Denmark", "North Macedonia", "Ecuador", "Cuba", "Papua New Guinea", "Argentina", "Colombia", "Mozambique", "Portugal", "Eswatini", "Poland", "Myanmar", "Philippines", "Turkey", "Peru", "Ethiopia", "Costa Rica", "Nepal", "Aruba", "Equatorial Guinea", "Netherlands", "Paraguay", "Croatia", "Egypt", "New Caledonia", "Togo", "Estonia", "Luxembourg", "Malaysia", "Kenya", "Hungary", "Japan", "Kazakhstan", "Spain", "Albania", "South Korea", "Bermuda", "Hong Kong", "Greenland", "South Africa", "Azerbaijan", "Honduras", "Kuwait", "Zimbabwe", "Haiti", "Bolivia", "Taiwan", "United Kingdom", "Belize", "Sri Lanka", "Belgium", "Switzerland", "Bahrain", "Iran", "Iraq", "Bahamas", "Sweden", "Indonesia", "Barbados", "Kyrgyzstan", "Ireland", "Suriname", "India", "Vietnam", "Israel", "Belarus", "Sudan", "Iceland", "Italy", "Syria", "Somalia", "Uzbekistan", "Ukraine", "Guatemala", "Guyana", "Algeria", "Slovakia", "Libya", "Sint Maarten (Dutch part)", "Liberia", "Bosnia and Herzegovina", "Lebanon", "Singapore", "Grenada", "Lithuania", "Slovenia", "Brazil", "Bonaire Sint Eustatius and Saba", "Guinea-Bissau", "Brunei", "Latvia"], "locationmode": "country names", "locations": ["Afghanistan", "Cameroon", "Mauritius", "Saint Pierre and Miquelon", "Canada", "France", "Mexico", "Australia", "Finland", "Moldova", "Saint Lucia", "Russia", "Turkmenistan", "Chile", "Fiji", "Mongolia", "Romania", "Montenegro", "China", "Thailand", "Saint Vincent and the Grenadines", "Malta", "Venezuela", "Samoa", "Tajikistan", "Sierra Leone", "Greece", "Bulgaria", "Germany", "Madagascar", "Serbia", "Malawi", "Saudi Arabia", "Faeroe Islands", "Uruguay", "Uganda", "Georgia", "Trinidad and Tobago", "United States", "Tanzania", "Angola", "Sao Tome and Principe", "Gambia", "Yemen", "Burundi", "Austria", "Qatar", "Morocco", "New Zealand", "Panama", "Zambia", "Cyprus", "Dominican Republic", "Nicaragua", "Pakistan", "Tunisia", "Czechia", "Dominica", "Nigeria", "Oceania", "Djibouti", "Norway", "Democratic Republic of Congo", "North Korea", "Armenia", "Denmark", "North Macedonia", "Ecuador", "Cuba", "Papua New Guinea", "Argentina", "Colombia", "Mozambique", "Portugal", "Eswatini", "Poland", "Myanmar", "Philippines", "Turkey", "Peru", "Ethiopia", "Costa Rica", "Nepal", "Aruba", "Equatorial Guinea", "Netherlands", "Paraguay", "Croatia", "Egypt", "New Caledonia", "Togo", "Estonia", "Luxembourg", "Malaysia", "Kenya", "Hungary", "Japan", "Kazakhstan", "Spain", "Albania", "South Korea", "Bermuda", "Hong Kong", "Greenland", "South Africa", "Azerbaijan", "Honduras", "Kuwait", "Zimbabwe", "Haiti", "Bolivia", "Taiwan", "United Kingdom", "Belize", "Sri Lanka", "Belgium", "Switzerland", "Bahrain", "Iran", "Iraq", "Bahamas", "Sweden", "Indonesia", "Barbados", "Kyrgyzstan", "Ireland", "Suriname", "India", "Vietnam", "Israel", "Belarus", "Sudan", "Iceland", "Italy", "Syria", "Somalia", "Uzbekistan", "Ukraine", "Guatemala", "Guyana", "Algeria", "Slovakia", "Libya", "Sint Maarten (Dutch ...

# %% [markdown]
# # Creating some interactive graphs and maps for CO2 emissions from gas production

# %%
# Showing the top 5 countries emitting the highest amount of CO2 from gas production

top_gas = data.groupby('country')['gas_co2'].sum().reset_index().sort_values(by=['gas_co2'], ascending=False).head(5)['country'].tolist()

fig = px.line(
    data[data['country'].isin(top_gas)],
    x='year',
    y='gas_co2',
    color='country',
    title = 'Top 5 countries with highest CO2 emissions from Gas Production measured in Million Tonnes Per Year '
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d8a61e9a-c768-4dc1-ac84-5a73d820b4b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d8a61e9a-c768-4dc1-ac84-5a73d820b4b6")) {
#                     Plotly.newPlot(
#                         'd8a61e9a-c768-4dc1-ac84-5a73d820b4b6',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Canada<br>year=%{x}<br>gas_co2=%{y}", "legendgroup": "country=Canada", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "country=Canada", "showlegend": true, "type": "scatter", "x": [1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990], "xaxis": "x", "y": [0.0037900378197200267, 0.0039639009876144896, 0.0044433690021688085, 0.005461454356437419, 0.006797691383914968, 0.007786202075603593, 0.009868079080855336, 0.012166836945026975, 0.015640515495330787, 0.019433241920739905, 0.020713914430642938, 0.023413274542488934, 0.020175297090928645, 0.030745102256636375, 0.034219677008836547, 0.0381504185262856, 0.04051818393647721, 0.04989335197433278, 0.052378519832947966, 0.05625638543851159, 0.06059758742449498, 0.06867774372210572, 0.07350199853022889, 0.07497893925543547, 0.07712803140291445, 0.0887912028821853, 0.09150310982058038, 0.09383054614543565, 0.10101987775806133, 0.10054309834919611, 0.09873725152802423, 0.09900611209693319, 0.10232654012295891, 0.10877919377677403, 0.1123586241508487, 0.10389578964349089, 0.1068873115735513, 0.11413131150185514, 0.12418580057715402, 0.11585112294097616], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Chad<br>year=%{x}<br>gas_co2=%{y}", "legendgroup": "country=Chad", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "country=Chad", "showlegend": true, "type": "scatter", "x": [1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990], "xaxis": "x", "y": [0.0955396031618003, 0.09467297592801707, 0.09380545249233747, 0.09293792905665789, 0.0920704056209783, 0.09120377838719508, 0.09033625495151548, 0.08946873151583588, 0.0886012080801563, 0.08773458084637308, 0.08686705741069349, 0.08599953397501389, 0.08513201053933431, 0.08426538330555108, 0.08339785986987149, 0.08253033643419189, 0.08166370920040866, 0.08079618576472909, 0.0799286623290495, 0.0790611388933699, 0.07819451165958667, 0.07732698822390709, 0.0764594647882275, 0.0755919413525479, 0.07472531411876468, 0.0738577906830851, 0.0729902672474055, 0.0721227438117259, 0.07125611657794267, 0.0703885931422631, 0.0695210697065835, 0.0686535462709039], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Russia<br>year=%{x}<br>gas_co2=%{y}", "legendgroup": "country=Russia", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "country=Russia", "showlegend": true, "type": "scatter", "x": [1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990], "xaxis": "x", "y": [0.007707336308723629, 0.007839974189385385, 0.008400996576508757, 0.009160079582728397, 0.010939040347009373, 0.014676202254843972, 0.022773386388485597, 0.033727662167733145, 0.04282231901202702, 0.05431341972719614, 0.07025954006918679, 0.08710096610564429, 0.10648491692208421, 0.1292609919162589, 0.14944345862235844, 0.16554372569052356, 0.18092434263590904, 0.19575738022261654, 0.20924253015719382, 0.19414780161674822, 0.2193041888476636, 0.23050043913892923, 0.2434156046674195, 0.25773870337509636, 0.28105249950708894, 0.30892617088777763, 0.3311367424853471, 0.34699055403201234, 0.3691715509670018, 0.38550931153770324, 0.41260059866286675, 0.4366779588105609, 0.4686634044917639, 0.5072556505529566, 0.5576813464537291, 0.5393791113261995, 0.6204593930920758, 0.6622044774246743, 0.6643670126005987, 0.7063137423598789], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": " ...
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gr

# %% [markdown]
# Here, also we have not considered the emissions for Chad while preparing the report because we had found that the country was not in the list of top emitters for this period.
#
# It is being shown in the top emitters because of the fact that there were a lot of missing values for these nations and while filling these missing values using the interpolate, median and mean method this discrepancy could have been created or arised.

# %%
# Showing the bottom 5 countries emitting the lowest amount of CO2 from gas production

bottom_gas = data.groupby('country')['gas_co2'].sum().reset_index().sort_values(by=['gas_co2'], ascending=True).head(5)['country'].tolist()

plt.figure(figsize=(15, 15))
g = sns.barplot(
    data = data[data['country'].isin(bottom_gas)],
    x ='country',
    y ='gas_co2',
    order = bottom_gas,
    ci=None
)

# g.set(ylim=(0,0.004))
plt.title('Bottom 5 countries with lowest CO2 emissions from Gas Production in Million Tonnes Per Year')
plt.show()

# %%
# Creating a time series chloropleth map for CO2 emissions from gas production
fig = px.choropleth(
    data.groupby(['country', 'year'])['gas_co2'].sum().reset_index().sort_values(by=['year'], ascending=True),
    locations='country',
    locationmode='country names',
    color='gas_co2',
    color_continuous_scale='Spectral_r', # (_r) is used for inverting the color ramp
    height=750,
    animation_frame='year',
    animation_group='country'
)

fig.update_layout(
    title='CO2 Emissions from Gas Production in Million Tonnes Per Year'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c89c30a0-5c6e-4d29-8c16-197a3ede0a3c" class="plotly-graph-div" style="height:750px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c89c30a0-5c6e-4d29-8c16-197a3ede0a3c")) {
#                     Plotly.newPlot(
#                         'c89c30a0-5c6e-4d29-8c16-197a3ede0a3c',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "year=1951<br>country=%{location}<br>gas_co2=%{z}", "ids": ["Afghanistan", "Cameroon", "Mauritius", "Saint Pierre and Miquelon", "Canada", "France", "Mexico", "Australia", "Finland", "Moldova", "Saint Lucia", "Russia", "Turkmenistan", "Chile", "Fiji", "Mongolia", "Romania", "Montenegro", "China", "Thailand", "Saint Vincent and the Grenadines", "Malta", "Venezuela", "Samoa", "Tajikistan", "Sierra Leone", "Greece", "Bulgaria", "Germany", "Madagascar", "Serbia", "Malawi", "Saudi Arabia", "Faeroe Islands", "Uruguay", "Uganda", "Georgia", "Trinidad and Tobago", "United States", "Tanzania", "Angola", "Sao Tome and Principe", "Gambia", "Yemen", "Burundi", "Austria", "Qatar", "Morocco", "New Zealand", "Panama", "Zambia", "Cyprus", "Dominican Republic", "Nicaragua", "Pakistan", "Tunisia", "Czechia", "Dominica", "Nigeria", "Oceania", "Djibouti", "Norway", "Democratic Republic of Congo", "North Korea", "Armenia", "Denmark", "North Macedonia", "Ecuador", "Cuba", "Papua New Guinea", "Argentina", "Colombia", "Mozambique", "Portugal", "Eswatini", "Poland", "Myanmar", "Philippines", "Turkey", "Peru", "Ethiopia", "Costa Rica", "Nepal", "Aruba", "Equatorial Guinea", "Netherlands", "Paraguay", "Croatia", "Egypt", "New Caledonia", "Togo", "Estonia", "Luxembourg", "Malaysia", "Kenya", "Hungary", "Japan", "Kazakhstan", "Spain", "Albania", "South Korea", "Bermuda", "Hong Kong", "Greenland", "South Africa", "Azerbaijan", "Honduras", "Kuwait", "Zimbabwe", "Haiti", "Bolivia", "Taiwan", "United Kingdom", "Belize", "Sri Lanka", "Belgium", "Switzerland", "Bahrain", "Iran", "Iraq", "Bahamas", "Sweden", "Indonesia", "Barbados", "Kyrgyzstan", "Ireland", "Suriname", "India", "Vietnam", "Israel", "Belarus", "Sudan", "Iceland", "Italy", "Syria", "Somalia", "Uzbekistan", "Ukraine", "Guatemala", "Guyana", "Algeria", "Slovakia", "Libya", "Sint Maarten (Dutch part)", "Liberia", "Bosnia and Herzegovina", "Lebanon", "Singapore", "Grenada", "Lithuania", "Slovenia", "Brazil", "Bonaire Sint Eustatius and Saba", "Guinea-Bissau", "Brunei", "Latvia"], "locationmode": "country names", "locations": ["Afghanistan", "Cameroon", "Mauritius", "Saint Pierre and Miquelon", "Canada", "France", "Mexico", "Australia", "Finland", "Moldova", "Saint Lucia", "Russia", "Turkmenistan", "Chile", "Fiji", "Mongolia", "Romania", "Montenegro", "China", "Thailand", "Saint Vincent and the Grenadines", "Malta", "Venezuela", "Samoa", "Tajikistan", "Sierra Leone", "Greece", "Bulgaria", "Germany", "Madagascar", "Serbia", "Malawi", "Saudi Arabia", "Faeroe Islands", "Uruguay", "Uganda", "Georgia", "Trinidad and Tobago", "United States", "Tanzania", "Angola", "Sao Tome and Principe", "Gambia", "Yemen", "Burundi", "Austria", "Qatar", "Morocco", "New Zealand", "Panama", "Zambia", "Cyprus", "Dominican Republic", "Nicaragua", "Pakistan", "Tunisia", "Czechia", "Dominica", "Nigeria", "Oceania", "Djibouti", "Norway", "Democratic Republic of Congo", "North Korea", "Armenia", "Denmark", "North Macedonia", "Ecuador", "Cuba", "Papua New Guinea", "Argentina", "Colombia", "Mozambique", "Portugal", "Eswatini", "Poland", "Myanmar", "Philippines", "Turkey", "Peru", "Ethiopia", "Costa Rica", "Nepal", "Aruba", "Equatorial Guinea", "Netherlands", "Paraguay", "Croatia", "Egypt", "New Caledonia", "Togo", "Estonia", "Luxembourg", "Malaysia", "Kenya", "Hungary", "Japan", "Kazakhstan", "Spain", "Albania", "South Korea", "Bermuda", "Hong Kong", "Greenland", "South Africa", "Azerbaijan", "Honduras", "Kuwait", "Zimbabwe", "Haiti", "Bolivia", "Taiwan", "United Kingdom", "Belize", "Sri Lanka", "Belgium", "Switzerland", "Bahrain", "Iran", "Iraq", "Bahamas", "Sweden", "Indonesia", "Barbados", "Kyrgyzstan", "Ireland", "Suriname", "India", "Vietnam", "Israel", "Belarus", "Sudan", "Iceland", "Italy", "Syria", "Somalia", "Uzbekistan", "Ukraine", "Guatemala", "Guyana", "Algeria", "Slovakia", "Libya", "Sint Maarten (Dutch par ...

# %% [markdown]
# # Creating some interactive graphs and maps for CO2 emissions from oil production

# %%
# Showing the top 5 countries emitting the highest amount of CO2 from oil production

top_oil = data.groupby('country')['oil_co2'].sum().reset_index().sort_values(by=['oil_co2'], ascending=False).head(5)['country'].tolist()

fig = px.line(
    data[data['country'].isin(top_oil)],
    x='year',
    y='oil_co2',
    color='country',
    title = 'Top 5 countries with highest CO2 emissions from Oil Production measured in Million Tonnes Per Year '
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0fae1542-9269-48a7-8602-aa81e3a0d601" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0fae1542-9269-48a7-8602-aa81e3a0d601")) {
#                     Plotly.newPlot(
#                         '0fae1542-9269-48a7-8602-aa81e3a0d601',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "country=France<br>year=%{x}<br>oil_co2=%{y}", "legendgroup": "country=France", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "country=France", "showlegend": true, "type": "scatter", "x": [1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990], "xaxis": "x", "y": [0.015280625423136036, 0.016542814147423, 0.017531869563403826, 0.019947956273001752, 0.02189638742094776, 0.024562344983812538, 0.02555099932298234, 0.027424830184078212, 0.029246922136552212, 0.031505786736229426, 0.03402815880074825, 0.03835256897718996, 0.04768402206243322, 0.05426809899217419, 0.06159777771360549, 0.06487617956690121, 0.07507034887265329, 0.08171298301680352, 0.09177319266767417, 0.10475043396510952, 0.11592403284337789, 0.12775940845983297, 0.14108999842777892, 0.13325817153894776, 0.11729330907620782, 0.13250976220958027, 0.12331427416327356, 0.1329774177712322, 0.13664045228629826, 0.1269644742203869, 0.1128626135448452, 0.10603668729805782, 0.104145610134088, 0.09883214454166546, 0.09685644017056994, 0.09789683341836163, 0.09848080125520998, 0.09572179387218806, 0.10022749076721181, 0.0956740657316764], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Germany<br>year=%{x}<br>oil_co2=%{y}", "legendgroup": "country=Germany", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "country=Germany", "showlegend": true, "type": "scatter", "x": [1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990], "xaxis": "x", "y": [0.0047335085236843875, 0.005527239532697386, 0.007160023230368895, 0.010082669952287904, 0.012275356878146447, 0.015891866483133916, 0.018541379896746785, 0.022400540972402707, 0.028537417257853886, 0.03662593330573925, 0.042681390998552914, 0.05338131816300403, 0.0661135015289048, 0.07649778124308142, 0.08763367890111372, 0.09826742839174615, 0.10231589772220458, 0.11677952968128832, 0.1303178774373438, 0.14874334613570514, 0.15457821158245658, 0.16473548182159461, 0.1734520841555408, 0.1568840021690234, 0.15142053384927856, 0.1684875553887076, 0.1674716278263883, 0.17202264640105755, 0.17339112048026542, 0.16571771893178808, 0.14520023358713474, 0.13844770439676443, 0.13400898732918137, 0.13460779500803757, 0.13674633656440813, 0.14340661808824332, 0.13887725766136924, 0.14117342240447153, 0.12975677097872368, 0.13307608266674367], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Japan<br>year=%{x}<br>oil_co2=%{y}", "legendgroup": "country=Japan", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "country=Japan", "showlegend": true, "type": "scatter", "x": [1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990], "xaxis": "x", "y": [0.0039237344422305, 0.005412531564745028, 0.009132117910165213, 0.009906597232249143, 0.011287905769409712, 0.01326561552456034, 0.017894443000567924, 0.01887788334119444, 0.02317943213940788, 0.03262398888535941, 0.0434875553887076, 0.04912709642849121, 0.06086300499581276, 0.07183526331494797, 0.08088997340058589, 0.09100713595862171, 0.1136599542451574, 0.13425123772303882, 0.16155373947975527, 0.20191851081784373, 0.22198879551820727, 0.2454951052585983, 0.26140261373736207, 0.255086857194195, 0.24335495939498367, 0.25888986751630777, 0.26848964098812494, 0.2615943284530307, 0.27268610766185053, 0.25323388232727223, 0.23714749359079257, 0.22761670533047126, 0.224722 ...
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"col

# %% [markdown]
# While doing the report we have not considered the emissions for Germany because the nation had got divided into East Germany and West Germany after the end of Second World War where the East Germany was controlled by the United States and West Germany was controlled by the Soviet Union.

# %%
# Showing the bottom 5 countries emitting the lowest amount of CO2 from oil production

bottom_oil = data.groupby('country')['oil_co2'].sum().reset_index().sort_values(by=['oil_co2'], ascending=True).head(5)['country'].tolist()

plt.figure(figsize=(15, 15))
g = sns.barplot(
    data = data[data['country'].isin(bottom_oil)],
    x ='country',
    y ='oil_co2',
    order = bottom_oil,
    ci=None
)

# g.set(ylim=(0,0.004))
plt.title('Bottom 5 countries with lowest CO2 emissions from Oil Production in Million Tonnes Per Year')
plt.show()

# %%
# Creating a time series chloropleth map for CO2 emissions from gas production
fig = px.choropleth(
    data.groupby(['country', 'year'])['oil_co2'].sum().reset_index().sort_values(by=['year'], ascending=True),
    locations='country',
    locationmode='country names',
    color='oil_co2',
    color_continuous_scale='Spectral_r', # (_r) is used for inverting the color ramp
    height=750,
    animation_frame='year',
    animation_group='country'
)

fig.update_layout(
    title='CO2 Emissions from Oil Production in Million Tonnes Per Year'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1eafbce7-cba6-4a62-a6d1-d7fcc355bc30" class="plotly-graph-div" style="height:750px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1eafbce7-cba6-4a62-a6d1-d7fcc355bc30")) {
#                     Plotly.newPlot(
#                         '1eafbce7-cba6-4a62-a6d1-d7fcc355bc30',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "year=1951<br>country=%{location}<br>oil_co2=%{z}", "ids": ["Afghanistan", "Cameroon", "Mauritius", "Saint Pierre and Miquelon", "Canada", "France", "Mexico", "Australia", "Finland", "Moldova", "Saint Lucia", "Russia", "Turkmenistan", "Chile", "Fiji", "Mongolia", "Romania", "Montenegro", "China", "Thailand", "Saint Vincent and the Grenadines", "Malta", "Venezuela", "Samoa", "Tajikistan", "Sierra Leone", "Greece", "Bulgaria", "Germany", "Madagascar", "Serbia", "Malawi", "Saudi Arabia", "Faeroe Islands", "Uruguay", "Uganda", "Georgia", "Trinidad and Tobago", "United States", "Tanzania", "Angola", "Sao Tome and Principe", "Gambia", "Yemen", "Burundi", "Austria", "Qatar", "Morocco", "New Zealand", "Panama", "Zambia", "Cyprus", "Dominican Republic", "Nicaragua", "Pakistan", "Tunisia", "Czechia", "Dominica", "Nigeria", "Oceania", "Djibouti", "Norway", "Democratic Republic of Congo", "North Korea", "Armenia", "Denmark", "North Macedonia", "Ecuador", "Cuba", "Papua New Guinea", "Argentina", "Colombia", "Mozambique", "Portugal", "Eswatini", "Poland", "Myanmar", "Philippines", "Turkey", "Peru", "Ethiopia", "Costa Rica", "Nepal", "Aruba", "Equatorial Guinea", "Netherlands", "Paraguay", "Croatia", "Egypt", "New Caledonia", "Togo", "Estonia", "Luxembourg", "Malaysia", "Kenya", "Hungary", "Japan", "Kazakhstan", "Spain", "Albania", "South Korea", "Bermuda", "Hong Kong", "Greenland", "South Africa", "Azerbaijan", "Honduras", "Kuwait", "Zimbabwe", "Haiti", "Bolivia", "Taiwan", "United Kingdom", "Belize", "Sri Lanka", "Belgium", "Switzerland", "Bahrain", "Iran", "Iraq", "Bahamas", "Sweden", "Indonesia", "Barbados", "Kyrgyzstan", "Ireland", "Suriname", "India", "Vietnam", "Israel", "Belarus", "Sudan", "Iceland", "Italy", "Syria", "Somalia", "Uzbekistan", "Ukraine", "Guatemala", "Guyana", "Algeria", "Slovakia", "Libya", "Sint Maarten (Dutch part)", "Liberia", "Bosnia and Herzegovina", "Lebanon", "Singapore", "Grenada", "Lithuania", "Slovenia", "Brazil", "Bonaire Sint Eustatius and Saba", "Guinea-Bissau", "Brunei", "Latvia"], "locationmode": "country names", "locations": ["Afghanistan", "Cameroon", "Mauritius", "Saint Pierre and Miquelon", "Canada", "France", "Mexico", "Australia", "Finland", "Moldova", "Saint Lucia", "Russia", "Turkmenistan", "Chile", "Fiji", "Mongolia", "Romania", "Montenegro", "China", "Thailand", "Saint Vincent and the Grenadines", "Malta", "Venezuela", "Samoa", "Tajikistan", "Sierra Leone", "Greece", "Bulgaria", "Germany", "Madagascar", "Serbia", "Malawi", "Saudi Arabia", "Faeroe Islands", "Uruguay", "Uganda", "Georgia", "Trinidad and Tobago", "United States", "Tanzania", "Angola", "Sao Tome and Principe", "Gambia", "Yemen", "Burundi", "Austria", "Qatar", "Morocco", "New Zealand", "Panama", "Zambia", "Cyprus", "Dominican Republic", "Nicaragua", "Pakistan", "Tunisia", "Czechia", "Dominica", "Nigeria", "Oceania", "Djibouti", "Norway", "Democratic Republic of Congo", "North Korea", "Armenia", "Denmark", "North Macedonia", "Ecuador", "Cuba", "Papua New Guinea", "Argentina", "Colombia", "Mozambique", "Portugal", "Eswatini", "Poland", "Myanmar", "Philippines", "Turkey", "Peru", "Ethiopia", "Costa Rica", "Nepal", "Aruba", "Equatorial Guinea", "Netherlands", "Paraguay", "Croatia", "Egypt", "New Caledonia", "Togo", "Estonia", "Luxembourg", "Malaysia", "Kenya", "Hungary", "Japan", "Kazakhstan", "Spain", "Albania", "South Korea", "Bermuda", "Hong Kong", "Greenland", "South Africa", "Azerbaijan", "Honduras", "Kuwait", "Zimbabwe", "Haiti", "Bolivia", "Taiwan", "United Kingdom", "Belize", "Sri Lanka", "Belgium", "Switzerland", "Bahrain", "Iran", "Iraq", "Bahamas", "Sweden", "Indonesia", "Barbados", "Kyrgyzstan", "Ireland", "Suriname", "India", "Vietnam", "Israel", "Belarus", "Sudan", "Iceland", "Italy", "Syria", "Somalia", "Uzbekistan", "Ukraine", "Guatemala", "Guyana", "Algeria", "Slovakia", "Libya", "Sint Maarten (Dutch par ...
